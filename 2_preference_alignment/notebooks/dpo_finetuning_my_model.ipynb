# %% [markdown]
# # Preference Alignment with Direct Preference Optimization (DPO)
#
# This notebook will guide you through the process of fine-tuning a language model using Direct Preference Optimization (DPO). We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#      <h2 style='margin: 0;color:blue'>Exercise: Aligning SmolLM2 with DPOTrainer</h2>
#      <p>Take a dataset from the Hugging Face hub and align a model on it. </p>
#      <p><b>Difficulty Levels</b></p>
#      <p>🐢 Use the `trl-lib/ultrafeedback_binarized` dataset</p>
#      <p>🐕 Try out the `argilla/ultrafeedback-binarized-preferences` dataset</p>
#      <p>🦁 Select a dataset that relates to a real-world use case you’re interested in, or use the model you trained in
#         <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
# Install the requirements in Google Colab
# !pip install transformers datasets trl huggingface_hub

# Authenticate to Hugging Face

from huggingface_hub import login
from dotenv import load_dotenv
import os

load_dotenv()

login(os.getenv("HF_TOKEN"))

# for convenience you can create an environment variable containing your hub token as HF_TOKEN
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Import libraries

# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
from trl import DPOTrainer, DPOConfig

# %% [markdown]
# ## Format dataset

# %%
# Load dataset
ds = load_dataset(path="trl-lib/ultrafeedback_binarized", split="train")

# %%
ds
# Out:
# Dataset({
#     features: ['chosen', 'rejected', 'score_chosen', 'score_rejected'],
#     num_rows: 62135
# })

# %%
ds[0]
# Out:
# {'chosen': [{'content': 'Use the pygame library to write a version of the classic game Snake, with a unique twist',
#    'role': 'user'},
#   {'content': "Sure, I'd be happy to help you write a version of the classic game Snake using the pygame library! Here's a basic outline of how we can approach this:\n\n1. First, we'll need to set up the game display and create a game object that we can use to handle the game's state.\n2. Next, we'll create the game's grid, which will be used to represent the game board. We'll need to define the size of the grid and the spaces within it.\n3. After that, we'll create the snake object, which will be used to represent the player's movement. We'll need to define the size of the snake and the speed at which it moves.\n4. We'll also need to create a food object, which will be used to represent the food that the player must collect to score points. We'll need to define the location of the food and the speed at which it moves.\n5. Once we have these objects set up, we can start handling the game's logic. We'll need to define the rules for the player's movements, such as how the player can move the snake and how the snake will grow as the player collects more food.\n6. We'll also need to add collisions detection to the game, so that the snake and the food can collide with each other.\n7. Finally, we'll need to add a user interface to the game, such as a menu and a scoreboard.\n\nNow, as for the unique twist, we could add a few features to make the game more interesting. For example, we could add power-ups that give the player special abilities, such as the ability to grow the snake faster or to change its direction. We could also add obstacles, such as walls or pits, that the player must avoid.\n\nHere's some sample code to get us started:\n```\nimport pygame\n\n# Initialize pygame\npygame.init()\n\n# Set up the game display\nwidth = 800\nheight = 600\nscreen = pygame.display.set_mode((width, height))\n\n# Define the colors\nWHITE = (255, 255, 255)\nBLACK = (0, 0, 0)\nGREEN = (0, 255, 0)\n\n# Define the game objects\nsnake = pygame.Rect(50, 50, 10, 10)\nfood = pygame.Rect(100, 100, 10, 10)\n\n# Define the game logic\ndef update_snake():\n    # Get the mouse position\n    mouse_pos = pygame.mouse.get_pos()\n\n    # Move the snake based on the mouse position\n    if mouse_pos[0] > snake.x:\n        snake.x += 10\n    elif mouse_pos[0] < snake.x:\n        snake.x -= 10\n    elif mouse_pos[1] > snake.y:\n        snake.y += 10\n    elif mouse_pos[1] < snake.y:\n        snake.y -= 10\n\n    # Update the snake's size\n    if snake.x == food.x and snake.y == food.y:\n        snake.width += 10\n        snake.height += 10\n\n# Define the game loop\ndef game_loop():\n    # Clear the screen\n    screen.fill(BLACK)\n\n    # Update the game objects\n    update_snake()\n\n    # Draw the game objects\n    screen.fill(WHITE)\n    screen.draw.rect(snake, GREEN)\n    screen.draw.rect(food, BLACK)\n\n    # Update the display\n    pygame.display.flip()\n\n# Start the game loop\ngame_loop()\n\n# Run the game\nwhile True:\n    for event in pygame.event.get():\n        if event.type == pygame.QUIT:\n            pygame.quit()\n            break\n\n    pygame.time.Clock().tick(60)\n```\nThis code sets up a basic game display, defines the snake and food objects, and updates the game state based on the player's movements. We've also added a simple user interface and some basic collision detection.\n\nAs for the unique twist, we could add a few features to make the game",
#    'role': 'assistant'}],
#  'rejected': [{'content': 'Use the pygame library to write a version of the classic game Snake, with a unique twist',
#    'role': 'user'},
#   {'content': 'Sure, here\'s an example of how to write a version of Snake game with a unique twist using the Pygame library:\n```python\nimport pygame\n\nclass SnakeGame:\n    def __init__(self, game_width, game_height):\n        pygame.init()\n        screen = pygame.display.set_mode((game_width, game_height))\n        pygame.display.set_caption("Snake Game")\n        self.speed = 5  # Speed of the snake\n        self.food_speed = 1  # Speed of the food\n        self.direction = 0  # Initial direction of the snake\n        self.snakelen = 0  # Length of the snake\n        self.food = pygame.image.load("snake_food.png")\n        self.head = pygame.image.load("snake_head.png")\n        self.tail = pygame.image.load("snake_tail.png")\n        self.game Quint()\n    def Quint(self):\n        for i in range(50):\n            pygame.draw.line(screen, (180, 100, 220), (0, 0, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 0, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 50, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 50, 300), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 80, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 80, 300), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 50, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 50, 300), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 80, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 80, 300), 2)\n            pygame.display.flip()\n        self.game.run()\n    def run(self):\n        while True:\n            for event in pygame.event. pygame.KEYDOWN:\n                if event.key == pygame.K_LEFT:\n                    self.direction = -1\n                if event.key == pygame.K_RIGHT:\n                    self.direction = 1\n            self.snakelen += 1\n            if self.snakelen == 0:\n                self.snakelen = 10\n            if self.snakelen > 20:\n                self.snakelen = 20\n            self.gameQuint()\n            self.foodCrossing()\n            self.headRun()\n            pygame.display.update()\ngame = SnakeGame(800, 600)\ngame.run()\n```\nIn this game, the snake moves with a constant speed, but the direction of the snake can be controlled by the user using the left and right arrow keys. The snake grows in length every 10 segments, and when it reaches a certain length, it resets to 10 segments. The food moves fast and randomly crosses the screen, and the snake can eat it by colliding with it. The snake\'s head and tail move independently of each other. The game ends when the snake dies or reaches the end of the screen.',
#    'role': 'assistant'}],
#  'score_chosen': 6.0,
#  'score_rejected': 4.0}

# %% [markdown]
# ## Select the model
#
# We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; width:80%; color:black'>
#      <p>🦁 change the model to the path or repo id of the model you trained in <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
model_name = "MilyaShams/SmolLM2-FT-smoltalk"  # model fine tuned on Instruction Tuning (module 1)

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
device
# Out:
# 'cuda'

# %%
# Model to fine-tune
model = AutoModelForCausalLM.from_pretrained(
    pretrained_model_name_or_path=model_name,
    torch_dtype=torch.float32,
).to(device)
model.config.use_cache = False
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# Set our name for the finetune to be saved &/ uploaded to
finetune_name = "SmolLM2-FT-DPO"
finetune_tags = ["smol-course", "DPO"]

# %% [markdown]
# ## Train model with DPO

# %%
# Training arguments
training_args = DPOConfig(
    # Training batch size per GPU
    per_device_train_batch_size=2,
    # Number of updates steps to accumulate before performing a backward/update pass
    # Effective batch size = per_device_train_batch_size * gradient_accumulation_steps
    gradient_accumulation_steps=4,
    # Saves memory by not storing activations during forward pass
    # Instead recomputes them during backward pass
    gradient_checkpointing=True,
    # Base learning rate for training
    learning_rate=5e-5,
    # Learning rate schedule - 'cosine' gradually decreases LR following cosine curve
    lr_scheduler_type="cosine",
    # Total number of training steps
    max_steps=200,
    # Disables model checkpointing during training
    save_strategy="no",
    # How often to log training metrics
    logging_steps=1,
    # Directory to save model outputs
    output_dir="smol_dpo_output",
    # Number of steps for learning rate warmup
    warmup_steps=100,
    # Use bfloat16 precision for faster training
    bf16=True,
    # Disable wandb/tensorboard logging
    report_to=None,
    # Keep all columns in dataset even if not used
    remove_unused_columns=False,
    # Enable MPS (Metal Performance Shaders) for Mac devices
    use_mps_device=device == "mps",
    # Model ID for HuggingFace Hub uploads
    hub_model_id=finetune_name,
)

# %%
trainer = DPOTrainer(
    # The model to be trained
    model=model,
    # Training configuration from above
    args=training_args,
    # Dataset containing preferred/rejected response pairs
    train_dataset=ds,
    # Tokenizer for processing inputs
    processing_class=tokenizer,
    # DPO-specific temperature parameter that controls the strength of the preference model
    # Lower values (like 0.1) make the model more conservative in following preferences
    #beta=0.1,
    # Maximum length of the input prompt in tokens
    #max_prompt_length=1024,
    # Maximum combined length of prompt + response in tokens
    #max_length=1536,
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Train the model
trainer.train()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
# {'loss': 0.6931, 'grad_norm': 162.1525115966797, 'learning_rate': 5.000000000000001e-07, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -532.1162109375, 'logps/rejected': -547.0089111328125, 'logits/chosen': 1.9700183868408203, 'logits/rejected': 1.5437158346176147, 'epoch': 0.0}
# {'loss': 0.6931, 'grad_norm': 132.79368591308594, 'learning_rate': 1.0000000000000002e-06, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -543.7830200195312, 'logps/rejected': -261.18408203125, 'logits/chosen': 4.004098415374756, 'logits/rejected': 3.5672640800476074, 'epoch': 0.0}
# {'loss': 0.6901, 'grad_norm': 162.13246154785156, 'learning_rate': 1.5e-06, 'rewards/chosen': 0.025383856147527695, 'rewards/rejected': 0.016274500638246536, 'rewards/accuracies': 0.5, 'rewards/margins': 0.00910935364663601, 'logps/chosen': -498.4207763671875, 'logps/rejected': -476.7001647949219, 'logits/chosen': 1.824306607246399, 'logits/rejected': 1.5131959915161133, 'epoch': 0.0}
# {'loss': 0.6773, 'grad_norm': 160.5719451904297, 'learning_rate': 2.0000000000000003e-06, 'rewards/chosen': 0.007825708948075771, 'rewards/rejected': -0.02768225595355034, 'rewards/accuracies': 0.625, 'rewards/margins': 0.03550796955823898, 'logps/chosen': -582.2108154296875, 'logps/rejected': -448.3486022949219, 'logits/chosen': 1.7791622877120972, 'logits/rejected': 2.5170507431030273, 'epoch': 0.0}
# {'loss': 0.7166, 'grad_norm': 138.04598999023438, 'learning_rate': 2.5e-06, 'rewards/chosen': -0.008025837130844593, 'rewards/rejected': 0.03763947635889053, 'rewards/accuracies': 0.25, 'rewards/margins': -0.04566531255841255, 'logps/chosen': -541.1346435546875, 'logps/rejected': -453.25396728515625, 'logits/chosen': 2.594311237335205, 'logits/rejected': 2.7412495613098145, 'epoch': 0.0}
# {'loss': 0.6815, 'grad_norm': 184.82003784179688, 'learning_rate': 3e-06, 'rewards/chosen': 0.005128480494022369, 'rewards/rejected': -0.02160339243710041, 'rewards/accuracies': 0.75, 'rewards/margins': 0.02673187665641308, 'logps/chosen': -920.3580322265625, 'logps/rejected': -642.357666015625, 'logits/chosen': 2.59516978263855, 'logits/rejected': 3.0179758071899414, 'epoch': 0.0}
# {'loss': 0.6993, 'grad_norm': 110.26244354248047, 'learning_rate': 3.5000000000000004e-06, 'rewards/chosen': -0.02639293670654297, 'rewards/rejected': -0.015082787722349167, 'rewards/accuracies': 0.5, 'rewards/margins': -0.011310148984193802, 'logps/chosen': -314.74139404296875, 'logps/rejected': -280.8717956542969, 'logits/chosen': 2.4612221717834473, 'logits/rejected': 2.8048269748687744, 'epoch': 0.0}
# {'loss': 0.7171, 'grad_norm': 127.74308013916016, 'learning_rate': 4.000000000000001e-06, 'rewards/chosen': -0.030756952241063118, 'rewards/rejected': 0.015140916220843792, 'rewards/accuracies': 0.25, 'rewards/margins': -0.045897867530584335, 'logps/chosen': -341.6405029296875, 'logps/rejected': -390.43701171875, 'logits/chosen': 5.3796281814575195, 'logits/rejected': 4.7360734939575195, 'epoch': 0.0}
# {'loss': 0.6845, 'grad_norm': 136.35801696777344, 'learning_rate': 4.5e-06, 'rewards/chosen': 0.036867380142211914, 'rewards/rejected': 0.01726360246539116, 'rewards/accuracies': 0.625, 'rewards/margins': 0.019603781402111053, 'logps/chosen': -404.3018493652344, 'logps/rejected': -233.24929809570312, 'logits/chosen': 3.2277774810791016, 'logits/rejected': 4.327061176300049, 'epoch': 0.0}
# {'loss': 0.7073, 'grad_norm': 142.81777954101562, 'learning_rate': 5e-06, 'rewards/chosen': 0.06324063241481781, 'rewards/rejected': 0.08050345629453659, 'rewards/accuracies': 0.5, 'rewards/margins': -0.017262835055589676, 'logps/chosen': -383.9393310546875, 'logps/rejected': -402.92340087890625, 'logits/chosen': 1.4189456701278687, 'logits/rejected': 2.2489919662475586, 'epoch': 0.0}
# {'loss': 0.6788, 'grad_norm': 104.78414154052734, 'learning_rate': 5.500000000000001e-06, 'rewards/chosen': 0.022015120834112167, 'rewards/rejected': -0.014066671952605247, 'rewards/accuracies': 0.5, 'rewards/margins': 0.036081794649362564, 'logps/chosen': -253.89601135253906, 'logps/rejected': -160.83880615234375, 'logits/chosen': 3.345738172531128, 'logits/rejected': 3.8774099349975586, 'epoch': 0.0}
# {'loss': 0.69, 'grad_norm': 125.48094177246094, 'learning_rate': 6e-06, 'rewards/chosen': 0.08966769278049469, 'rewards/rejected': 0.07341890037059784, 'rewards/accuracies': 0.375, 'rewards/margins': 0.016248799860477448, 'logps/chosen': -456.0836181640625, 'logps/rejected': -404.9091796875, 'logits/chosen': 2.9740896224975586, 'logits/rejected': 3.0272655487060547, 'epoch': 0.0}
# {'loss': 0.6227, 'grad_norm': 154.7483673095703, 'learning_rate': 6.5000000000000004e-06, 'rewards/chosen': 0.20229531824588776, 'rewards/rejected': 0.036342911422252655, 'rewards/accuracies': 0.625, 'rewards/margins': 0.1659524142742157, 'logps/chosen': -835.67138671875, 'logps/rejected': -478.2500305175781, 'logits/chosen': 2.3748364448547363, 'logits/rejected': -0.5059828758239746, 'epoch': 0.0}
# {'loss': 0.6798, 'grad_norm': 128.69442749023438, 'learning_rate': 7.000000000000001e-06, 'rewards/chosen': -0.022480202838778496, 'rewards/rejected': -0.055570315569639206, 'rewards/accuracies': 0.5, 'rewards/margins': 0.033090122044086456, 'logps/chosen': -404.57867431640625, 'logps/rejected': -258.6776123046875, 'logits/chosen': 3.0973000526428223, 'logits/rejected': 4.928375720977783, 'epoch': 0.0}
# {'loss': 0.6808, 'grad_norm': 145.8956756591797, 'learning_rate': 7.5e-06, 'rewards/chosen': 0.1203225702047348, 'rewards/rejected': 0.0882180705666542, 'rewards/accuracies': 0.5, 'rewards/margins': 0.0321044996380806, 'logps/chosen': -552.6931762695312, 'logps/rejected': -456.5435791015625, 'logits/chosen': 4.391720294952393, 'logits/rejected': 4.254328727722168, 'epoch': 0.0}
# {'loss': 0.648, 'grad_norm': 123.44677734375, 'learning_rate': 8.000000000000001e-06, 'rewards/chosen': 0.1092309057712555, 'rewards/rejected': 0.010992147028446198, 'rewards/accuracies': 0.625, 'rewards/margins': 0.09823876619338989, 'logps/chosen': -619.1806640625, 'logps/rejected': -362.6111145019531, 'logits/chosen': 1.8012983798980713, 'logits/rejected': 3.8326988220214844, 'epoch': 0.0}
# {'loss': 0.6975, 'grad_norm': 123.12020111083984, 'learning_rate': 8.500000000000002e-06, 'rewards/chosen': 0.04656028747558594, 'rewards/rejected': 0.04993009567260742, 'rewards/accuracies': 0.5, 'rewards/margins': -0.0033698081970214844, 'logps/chosen': -444.794189453125, 'logps/rejected': -303.27166748046875, 'logits/chosen': 4.0311970710754395, 'logits/rejected': 3.0191125869750977, 'epoch': 0.0}
# {'loss': 0.6566, 'grad_norm': 161.6549530029297, 'learning_rate': 9e-06, 'rewards/chosen': 0.23423539102077484, 'rewards/rejected': 0.12609881162643433, 'rewards/accuracies': 0.75, 'rewards/margins': 0.10813656449317932, 'logps/chosen': -684.85791015625, 'logps/rejected': -686.8577880859375, 'logits/chosen': -0.5373070240020752, 'logits/rejected': 0.37598392367362976, 'epoch': 0.0}
# {'loss': 0.6839, 'grad_norm': 121.64897918701172, 'learning_rate': 9.5e-06, 'rewards/chosen': 0.09529165923595428, 'rewards/rejected': 0.046409040689468384, 'rewards/accuracies': 0.625, 'rewards/margins': 0.0488826259970665, 'logps/chosen': -306.5784912109375, 'logps/rejected': -373.09466552734375, 'logits/chosen': 3.7017829418182373, 'logits/rejected': 3.415822982788086, 'epoch': 0.0}
# {'loss': 0.755, 'grad_norm': 170.24217224121094, 'learning_rate': 1e-05, 'rewards/chosen': 0.16046182811260223, 'rewards/rejected': 0.24582670629024506, 'rewards/accuracies': 0.5, 'rewards/margins': -0.08536490052938461, 'logps/chosen': -419.5755920410156, 'logps/rejected': -453.3817138671875, 'logits/chosen': 2.58354115486145, 'logits/rejected': 3.338252067565918, 'epoch': 0.0}
# {'loss': 0.6589, 'grad_norm': 139.599365234375, 'learning_rate': 1.05e-05, 'rewards/chosen': 0.28040772676467896, 'rewards/rejected': 0.13485842943191528, 'rewards/accuracies': 0.75, 'rewards/margins': 0.14554929733276367, 'logps/chosen': -555.4873046875, 'logps/rejected': -510.9787902832031, 'logits/chosen': 2.7177963256835938, 'logits/rejected': 3.076673984527588, 'epoch': 0.0}
# {'loss': 0.6415, 'grad_norm': 122.10971069335938, 'learning_rate': 1.1000000000000001e-05, 'rewards/chosen': -0.08232640475034714, 'rewards/rejected': -0.23080845177173615, 'rewards/accuracies': 0.375, 'rewards/margins': 0.1484820395708084, 'logps/chosen': -424.1318054199219, 'logps/rejected': -334.800048828125, 'logits/chosen': 1.952535629272461, 'logits/rejected': 3.051656723022461, 'epoch': 0.0}
# {'loss': 0.6237, 'grad_norm': 177.1315155029297, 'learning_rate': 1.1500000000000002e-05, 'rewards/chosen': 0.2352164387702942, 'rewards/rejected': 0.01174011081457138, 'rewards/accuracies': 0.875, 'rewards/margins': 0.2234763205051422, 'logps/chosen': -628.3348388671875, 'logps/rejected': -761.2940673828125, 'logits/chosen': 1.2756096124649048, 'logits/rejected': 3.042310953140259, 'epoch': 0.0}
# {'loss': 0.5998, 'grad_norm': 136.9435272216797, 'learning_rate': 1.2e-05, 'rewards/chosen': 0.2873646914958954, 'rewards/rejected': 0.04111647233366966, 'rewards/accuracies': 0.875, 'rewards/margins': 0.2462482452392578, 'logps/chosen': -434.3741455078125, 'logps/rejected': -419.9188537597656, 'logits/chosen': 2.324514865875244, 'logits/rejected': 2.561520576477051, 'epoch': 0.0}
# {'loss': 0.7579, 'grad_norm': 135.1246337890625, 'learning_rate': 1.25e-05, 'rewards/chosen': -0.018276503309607506, 'rewards/rejected': 0.0845705047249794, 'rewards/accuracies': 0.375, 'rewards/margins': -0.10284700244665146, 'logps/chosen': -407.47802734375, 'logps/rejected': -412.3311462402344, 'logits/chosen': 3.3886454105377197, 'logits/rejected': 4.115326881408691, 'epoch': 0.0}
# {'loss': 0.6689, 'grad_norm': 154.17184448242188, 'learning_rate': 1.3000000000000001e-05, 'rewards/chosen': 0.17453336715698242, 'rewards/rejected': 0.08311128616333008, 'rewards/accuracies': 0.5, 'rewards/margins': 0.09142208099365234, 'logps/chosen': -693.2664794921875, 'logps/rejected': -631.2496337890625, 'logits/chosen': 3.8236992359161377, 'logits/rejected': 1.4211351871490479, 'epoch': 0.0}
# {'loss': 0.5954, 'grad_norm': 93.35342407226562, 'learning_rate': 1.3500000000000001e-05, 'rewards/chosen': 0.1841297149658203, 'rewards/rejected': -0.0505797378718853, 'rewards/accuracies': 0.625, 'rewards/margins': 0.2347094565629959, 'logps/chosen': -356.695068359375, 'logps/rejected': -223.48623657226562, 'logits/chosen': 3.0051708221435547, 'logits/rejected': 3.6248598098754883, 'epoch': 0.0}
# {'loss': 0.6222, 'grad_norm': 143.3273468017578, 'learning_rate': 1.4000000000000001e-05, 'rewards/chosen': 0.3444908559322357, 'rewards/rejected': 0.16318613290786743, 'rewards/accuracies': 0.625, 'rewards/margins': 0.1813046932220459, 'logps/chosen': -533.1326904296875, 'logps/rejected': -477.32354736328125, 'logits/chosen': 1.299757480621338, 'logits/rejected': 3.6849515438079834, 'epoch': 0.0}
# {'loss': 0.7267, 'grad_norm': 169.87110900878906, 'learning_rate': 1.45e-05, 'rewards/chosen': 0.16970796883106232, 'rewards/rejected': 0.2079060673713684, 'rewards/accuracies': 0.375, 'rewards/margins': -0.03819809481501579, 'logps/chosen': -602.4684448242188, 'logps/rejected': -517.9742431640625, 'logits/chosen': 0.3247931897640228, 'logits/rejected': 1.410321831703186, 'epoch': 0.0}
# {'loss': 0.7041, 'grad_norm': 124.48042297363281, 'learning_rate': 1.5e-05, 'rewards/chosen': 0.16477762162685394, 'rewards/rejected': 0.004556089639663696, 'rewards/accuracies': 0.5, 'rewards/margins': 0.16022153198719025, 'logps/chosen': -370.78765869140625, 'logps/rejected': -270.419189453125, 'logits/chosen': 3.3073112964630127, 'logits/rejected': 2.2188096046447754, 'epoch': 0.0}
# {'loss': 0.6656, 'grad_norm': 121.1092529296875, 'learning_rate': 1.55e-05, 'rewards/chosen': -0.08187070488929749, 'rewards/rejected': -0.3096275329589844, 'rewards/accuracies': 0.625, 'rewards/margins': 0.2277567982673645, 'logps/chosen': -346.8874816894531, 'logps/rejected': -282.19256591796875, 'logits/chosen': 3.324763774871826, 'logits/rejected': 3.498152256011963, 'epoch': 0.0}
# {'loss': 0.6806, 'grad_norm': 139.18589782714844, 'learning_rate': 1.6000000000000003e-05, 'rewards/chosen': 0.24251900613307953, 'rewards/rejected': 0.13352584838867188, 'rewards/accuracies': 0.5, 'rewards/margins': 0.10899315029382706, 'logps/chosen': -721.3123779296875, 'logps/rejected': -564.2906494140625, 'logits/chosen': 3.464831590652466, 'logits/rejected': 2.5764312744140625, 'epoch': 0.0}
# {'loss': 0.6612, 'grad_norm': 129.9115753173828, 'learning_rate': 1.65e-05, 'rewards/chosen': 0.15787163376808167, 'rewards/rejected': -0.17121870815753937, 'rewards/accuracies': 0.625, 'rewards/margins': 0.329090416431427, 'logps/chosen': -395.5627136230469, 'logps/rejected': -291.0916748046875, 'logits/chosen': 0.8262940049171448, 'logits/rejected': 1.9633123874664307, 'epoch': 0.0}
# {'loss': 0.79, 'grad_norm': 179.19142150878906, 'learning_rate': 1.7000000000000003e-05, 'rewards/chosen': 0.2972824275493622, 'rewards/rejected': 0.37271884083747864, 'rewards/accuracies': 0.25, 'rewards/margins': -0.07543639838695526, 'logps/chosen': -669.6726684570312, 'logps/rejected': -633.2647705078125, 'logits/chosen': 0.4508379101753235, 'logits/rejected': 2.024517297744751, 'epoch': 0.0}
# {'loss': 0.5557, 'grad_norm': 79.26443481445312, 'learning_rate': 1.75e-05, 'rewards/chosen': 0.0461433008313179, 'rewards/rejected': -0.31703731417655945, 'rewards/accuracies': 0.875, 'rewards/margins': 0.36318060755729675, 'logps/chosen': -264.5550842285156, 'logps/rejected': -318.154541015625, 'logits/chosen': 1.599942922592163, 'logits/rejected': 1.2757439613342285, 'epoch': 0.0}
# {'loss': 0.5561, 'grad_norm': 132.85711669921875, 'learning_rate': 1.8e-05, 'rewards/chosen': 0.5355125069618225, 'rewards/rejected': 0.13211917877197266, 'rewards/accuracies': 0.625, 'rewards/margins': 0.40339335799217224, 'logps/chosen': -828.586669921875, 'logps/rejected': -488.60491943359375, 'logits/chosen': 1.6399530172348022, 'logits/rejected': 1.7240232229232788, 'epoch': 0.0}
# {'loss': 0.7485, 'grad_norm': 123.52582550048828, 'learning_rate': 1.85e-05, 'rewards/chosen': 0.015665777027606964, 'rewards/rejected': 0.10440650582313538, 'rewards/accuracies': 0.375, 'rewards/margins': -0.08874073624610901, 'logps/chosen': -472.4901123046875, 'logps/rejected': -338.52398681640625, 'logits/chosen': 1.9289981126785278, 'logits/rejected': 2.5818774700164795, 'epoch': 0.0}
# {'loss': 0.5929, 'grad_norm': 137.44808959960938, 'learning_rate': 1.9e-05, 'rewards/chosen': 0.330445796251297, 'rewards/rejected': 0.028302006423473358, 'rewards/accuracies': 0.75, 'rewards/margins': 0.30214378237724304, 'logps/chosen': -517.8638916015625, 'logps/rejected': -496.8609924316406, 'logits/chosen': 2.970093250274658, 'logits/rejected': 2.3705966472625732, 'epoch': 0.0}
# {'loss': 0.7091, 'grad_norm': 116.11217498779297, 'learning_rate': 1.9500000000000003e-05, 'rewards/chosen': -0.05776243284344673, 'rewards/rejected': -0.11653146892786026, 'rewards/accuracies': 0.375, 'rewards/margins': 0.05876905098557472, 'logps/chosen': -517.1893920898438, 'logps/rejected': -359.76348876953125, 'logits/chosen': 3.3232340812683105, 'logits/rejected': 4.75072717666626, 'epoch': 0.01}
# {'loss': 0.5819, 'grad_norm': 132.2488555908203, 'learning_rate': 2e-05, 'rewards/chosen': 0.41970720887184143, 'rewards/rejected': 0.083404541015625, 'rewards/accuracies': 0.75, 'rewards/margins': 0.33630266785621643, 'logps/chosen': -341.2088623046875, 'logps/rejected': -367.9718017578125, 'logits/chosen': 3.982407569885254, 'logits/rejected': 3.354868173599243, 'epoch': 0.01}
# {'loss': 0.5033, 'grad_norm': 121.07076263427734, 'learning_rate': 2.05e-05, 'rewards/chosen': 1.12265944480896, 'rewards/rejected': 0.26003170013427734, 'rewards/accuracies': 0.625, 'rewards/margins': 0.8626277446746826, 'logps/chosen': -775.2479248046875, 'logps/rejected': -354.5551452636719, 'logits/chosen': 2.8825979232788086, 'logits/rejected': 4.012821674346924, 'epoch': 0.01}
# {'loss': 0.9119, 'grad_norm': 184.13186645507812, 'learning_rate': 2.1e-05, 'rewards/chosen': -0.23218373954296112, 'rewards/rejected': 0.07479191571474075, 'rewards/accuracies': 0.25, 'rewards/margins': -0.30697566270828247, 'logps/chosen': -263.08642578125, 'logps/rejected': -519.4027099609375, 'logits/chosen': 2.9099807739257812, 'logits/rejected': 3.0952930450439453, 'epoch': 0.01}
# {'loss': 0.686, 'grad_norm': 158.70834350585938, 'learning_rate': 2.15e-05, 'rewards/chosen': 0.8759851455688477, 'rewards/rejected': 0.5179064273834229, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3580787777900696, 'logps/chosen': -769.685302734375, 'logps/rejected': -604.0059814453125, 'logits/chosen': 2.891173839569092, 'logits/rejected': 1.7382407188415527, 'epoch': 0.01}
# {'loss': 0.7447, 'grad_norm': 110.62669372558594, 'learning_rate': 2.2000000000000003e-05, 'rewards/chosen': 0.07170328497886658, 'rewards/rejected': 0.1346566081047058, 'rewards/accuracies': 0.25, 'rewards/margins': -0.06295333802700043, 'logps/chosen': -352.86029052734375, 'logps/rejected': -354.7379455566406, 'logits/chosen': 3.323751926422119, 'logits/rejected': 2.855229139328003, 'epoch': 0.01}
# {'loss': 0.8155, 'grad_norm': 156.1016845703125, 'learning_rate': 2.25e-05, 'rewards/chosen': 0.3514627516269684, 'rewards/rejected': 0.418376624584198, 'rewards/accuracies': 0.625, 'rewards/margins': -0.06691387295722961, 'logps/chosen': -316.0470886230469, 'logps/rejected': -430.96685791015625, 'logits/chosen': 4.862607479095459, 'logits/rejected': 4.525835990905762, 'epoch': 0.01}
# {'loss': 0.6492, 'grad_norm': 104.1115493774414, 'learning_rate': 2.3000000000000003e-05, 'rewards/chosen': 0.06232242286205292, 'rewards/rejected': -0.06396713107824326, 'rewards/accuracies': 0.75, 'rewards/margins': 0.12628956139087677, 'logps/chosen': -302.9303894042969, 'logps/rejected': -229.41091918945312, 'logits/chosen': 1.8254438638687134, 'logits/rejected': 3.807743549346924, 'epoch': 0.01}
# {'loss': 0.6798, 'grad_norm': 141.12350463867188, 'learning_rate': 2.35e-05, 'rewards/chosen': 0.7509146928787231, 'rewards/rejected': 0.5884271264076233, 'rewards/accuracies': 0.75, 'rewards/margins': 0.16248761117458344, 'logps/chosen': -579.4462280273438, 'logps/rejected': -601.7982177734375, 'logits/chosen': 2.494296073913574, 'logits/rejected': 2.6119143962860107, 'epoch': 0.01}
# {'loss': 0.5223, 'grad_norm': 77.78449249267578, 'learning_rate': 2.4e-05, 'rewards/chosen': 0.5715363621711731, 'rewards/rejected': 0.050067611038684845, 'rewards/accuracies': 0.875, 'rewards/margins': 0.5214687585830688, 'logps/chosen': -491.4040222167969, 'logps/rejected': -387.3119201660156, 'logits/chosen': 2.6867270469665527, 'logits/rejected': 3.124537706375122, 'epoch': 0.01}
# {'loss': 0.6212, 'grad_norm': 106.69877624511719, 'learning_rate': 2.45e-05, 'rewards/chosen': 0.3233872652053833, 'rewards/rejected': 0.026383601129055023, 'rewards/accuracies': 0.625, 'rewards/margins': 0.2970036268234253, 'logps/chosen': -448.65771484375, 'logps/rejected': -158.77645874023438, 'logits/chosen': 3.910949945449829, 'logits/rejected': 4.193512439727783, 'epoch': 0.01}
# {'loss': 0.6711, 'grad_norm': 106.8812484741211, 'learning_rate': 2.5e-05, 'rewards/chosen': 0.042368754744529724, 'rewards/rejected': -0.06395817548036575, 'rewards/accuracies': 0.375, 'rewards/margins': 0.10632692277431488, 'logps/chosen': -569.1427001953125, 'logps/rejected': -437.7392578125, 'logits/chosen': 0.5146626234054565, 'logits/rejected': 1.5314810276031494, 'epoch': 0.01}
# {'loss': 0.8042, 'grad_norm': 141.1754608154297, 'learning_rate': 2.5500000000000003e-05, 'rewards/chosen': 0.12835173308849335, 'rewards/rejected': 0.274982213973999, 'rewards/accuracies': 0.25, 'rewards/margins': -0.14663049578666687, 'logps/chosen': -416.068359375, 'logps/rejected': -314.87152099609375, 'logits/chosen': 3.718297243118286, 'logits/rejected': 3.996143341064453, 'epoch': 0.01}
# {'loss': 0.4411, 'grad_norm': 65.86270904541016, 'learning_rate': 2.6000000000000002e-05, 'rewards/chosen': 0.9328656196594238, 'rewards/rejected': 0.21584172546863556, 'rewards/accuracies': 0.875, 'rewards/margins': 0.7170239090919495, 'logps/chosen': -418.99560546875, 'logps/rejected': -266.60552978515625, 'logits/chosen': 4.114264488220215, 'logits/rejected': 3.3950047492980957, 'epoch': 0.01}
# {'loss': 0.7438, 'grad_norm': 122.36039733886719, 'learning_rate': 2.6500000000000004e-05, 'rewards/chosen': 0.3256807327270508, 'rewards/rejected': 0.18687549233436584, 'rewards/accuracies': 0.5, 'rewards/margins': 0.13880522549152374, 'logps/chosen': -453.8155517578125, 'logps/rejected': -352.34832763671875, 'logits/chosen': 3.745889663696289, 'logits/rejected': 4.455320835113525, 'epoch': 0.01}
# {'loss': 0.5554, 'grad_norm': 93.2369613647461, 'learning_rate': 2.7000000000000002e-05, 'rewards/chosen': 0.2786109447479248, 'rewards/rejected': -0.10979128628969193, 'rewards/accuracies': 0.625, 'rewards/margins': 0.38840222358703613, 'logps/chosen': -372.6396179199219, 'logps/rejected': -403.4956359863281, 'logits/chosen': 4.283963680267334, 'logits/rejected': 3.5418660640716553, 'epoch': 0.01}
# {'loss': 0.6195, 'grad_norm': 105.53397369384766, 'learning_rate': 2.7500000000000004e-05, 'rewards/chosen': 0.5146039128303528, 'rewards/rejected': 0.1462375670671463, 'rewards/accuracies': 0.625, 'rewards/margins': 0.3683663606643677, 'logps/chosen': -319.3825988769531, 'logps/rejected': -467.9640808105469, 'logits/chosen': 3.7469379901885986, 'logits/rejected': 4.064347267150879, 'epoch': 0.01}
# {'loss': 0.6998, 'grad_norm': 158.61363220214844, 'learning_rate': 2.8000000000000003e-05, 'rewards/chosen': 0.7844945192337036, 'rewards/rejected': 0.22296859323978424, 'rewards/accuracies': 0.5, 'rewards/margins': 0.5615259408950806, 'logps/chosen': -447.0166320800781, 'logps/rejected': -546.4088134765625, 'logits/chosen': 2.5308988094329834, 'logits/rejected': 1.773893117904663, 'epoch': 0.01}
# {'loss': 0.6136, 'grad_norm': 135.0307159423828, 'learning_rate': 2.8499999999999998e-05, 'rewards/chosen': 0.19046849012374878, 'rewards/rejected': -0.055281445384025574, 'rewards/accuracies': 0.75, 'rewards/margins': 0.24574995040893555, 'logps/chosen': -748.9002685546875, 'logps/rejected': -542.9130249023438, 'logits/chosen': 0.9981125593185425, 'logits/rejected': 1.380616545677185, 'epoch': 0.01}
# {'loss': 0.8161, 'grad_norm': 155.19290161132812, 'learning_rate': 2.9e-05, 'rewards/chosen': 0.08995294570922852, 'rewards/rejected': 0.27493399381637573, 'rewards/accuracies': 0.25, 'rewards/margins': -0.1849810630083084, 'logps/chosen': -545.544189453125, 'logps/rejected': -569.5855102539062, 'logits/chosen': 3.234372138977051, 'logits/rejected': 2.093346357345581, 'epoch': 0.01}
# {'loss': 1.0239, 'grad_norm': 118.39140319824219, 'learning_rate': 2.95e-05, 'rewards/chosen': 0.15939603745937347, 'rewards/rejected': 0.4769496023654938, 'rewards/accuracies': 0.5, 'rewards/margins': -0.3175535500049591, 'logps/chosen': -198.48416137695312, 'logps/rejected': -293.12921142578125, 'logits/chosen': 3.0526556968688965, 'logits/rejected': 1.8950074911117554, 'epoch': 0.01}
# {'loss': 1.1511, 'grad_norm': 179.8539581298828, 'learning_rate': 3e-05, 'rewards/chosen': 0.08296285569667816, 'rewards/rejected': 0.53568035364151, 'rewards/accuracies': 0.375, 'rewards/margins': -0.45271754264831543, 'logps/chosen': -571.2719116210938, 'logps/rejected': -316.750244140625, 'logits/chosen': 1.9526435136795044, 'logits/rejected': 0.5013198852539062, 'epoch': 0.01}
# {'loss': 0.637, 'grad_norm': 148.91302490234375, 'learning_rate': 3.05e-05, 'rewards/chosen': 0.6021277904510498, 'rewards/rejected': 0.18033170700073242, 'rewards/accuracies': 0.625, 'rewards/margins': 0.421796053647995, 'logps/chosen': -674.3958740234375, 'logps/rejected': -418.78546142578125, 'logits/chosen': 2.8088173866271973, 'logits/rejected': 1.9185576438903809, 'epoch': 0.01}
# {'loss': 0.6344, 'grad_norm': 156.6715850830078, 'learning_rate': 3.1e-05, 'rewards/chosen': 0.2956445813179016, 'rewards/rejected': 0.008051306009292603, 'rewards/accuracies': 0.75, 'rewards/margins': 0.287593275308609, 'logps/chosen': -520.383056640625, 'logps/rejected': -559.520751953125, 'logits/chosen': 1.738877773284912, 'logits/rejected': 0.7247691750526428, 'epoch': 0.01}
# {'loss': 0.652, 'grad_norm': 83.09495544433594, 'learning_rate': 3.15e-05, 'rewards/chosen': 0.04436703026294708, 'rewards/rejected': -0.0664500743150711, 'rewards/accuracies': 0.625, 'rewards/margins': 0.11081710457801819, 'logps/chosen': -212.46493530273438, 'logps/rejected': -228.1298828125, 'logits/chosen': 3.113238573074341, 'logits/rejected': 2.763314723968506, 'epoch': 0.01}
# {'loss': 0.6063, 'grad_norm': 82.24284362792969, 'learning_rate': 3.2000000000000005e-05, 'rewards/chosen': 0.49785134196281433, 'rewards/rejected': 0.13813580572605133, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3597155213356018, 'logps/chosen': -423.3968505859375, 'logps/rejected': -270.25347900390625, 'logits/chosen': 3.949556827545166, 'logits/rejected': 4.6872029304504395, 'epoch': 0.01}
# {'loss': 0.5598, 'grad_norm': 92.55610656738281, 'learning_rate': 3.2500000000000004e-05, 'rewards/chosen': 0.2489035278558731, 'rewards/rejected': -0.1378624439239502, 'rewards/accuracies': 0.625, 'rewards/margins': 0.3867659568786621, 'logps/chosen': -333.99810791015625, 'logps/rejected': -318.6439514160156, 'logits/chosen': 1.3783674240112305, 'logits/rejected': 2.6837854385375977, 'epoch': 0.01}
# {'loss': 0.7932, 'grad_norm': 124.1446533203125, 'learning_rate': 3.3e-05, 'rewards/chosen': -0.1727662980556488, 'rewards/rejected': -0.05055847018957138, 'rewards/accuracies': 0.5, 'rewards/margins': -0.12220785766839981, 'logps/chosen': -366.1468505859375, 'logps/rejected': -307.02001953125, 'logits/chosen': 1.6347891092300415, 'logits/rejected': 2.4377729892730713, 'epoch': 0.01}
# {'loss': 0.5194, 'grad_norm': 107.69298553466797, 'learning_rate': 3.35e-05, 'rewards/chosen': 0.5252992510795593, 'rewards/rejected': -0.1530660092830658, 'rewards/accuracies': 0.75, 'rewards/margins': 0.6783653497695923, 'logps/chosen': -670.0914916992188, 'logps/rejected': -575.8843994140625, 'logits/chosen': 2.410332202911377, 'logits/rejected': 2.0467753410339355, 'epoch': 0.01}
# {'loss': 0.6856, 'grad_norm': 121.17086029052734, 'learning_rate': 3.4000000000000007e-05, 'rewards/chosen': -0.34344273805618286, 'rewards/rejected': -0.5162575840950012, 'rewards/accuracies': 0.25, 'rewards/margins': 0.17281481623649597, 'logps/chosen': -462.6157531738281, 'logps/rejected': -436.00250244140625, 'logits/chosen': -0.27309995889663696, 'logits/rejected': -0.9191607236862183, 'epoch': 0.01}
# {'loss': 0.7951, 'grad_norm': 161.6227569580078, 'learning_rate': 3.45e-05, 'rewards/chosen': -0.043356698006391525, 'rewards/rejected': 0.010425472632050514, 'rewards/accuracies': 0.375, 'rewards/margins': -0.05378219485282898, 'logps/chosen': -407.670166015625, 'logps/rejected': -475.27716064453125, 'logits/chosen': 2.053567886352539, 'logits/rejected': 0.174028217792511, 'epoch': 0.01}
# {'loss': 0.6227, 'grad_norm': 84.97191619873047, 'learning_rate': 3.5e-05, 'rewards/chosen': -0.2303609848022461, 'rewards/rejected': -0.46096718311309814, 'rewards/accuracies': 0.5, 'rewards/margins': 0.23060616850852966, 'logps/chosen': -346.2720031738281, 'logps/rejected': -253.58370971679688, 'logits/chosen': 1.9895434379577637, 'logits/rejected': 2.9983646869659424, 'epoch': 0.01}
# {'loss': 0.4587, 'grad_norm': 69.12425994873047, 'learning_rate': 3.55e-05, 'rewards/chosen': 0.09145870804786682, 'rewards/rejected': -0.8306851387023926, 'rewards/accuracies': 0.625, 'rewards/margins': 0.922143816947937, 'logps/chosen': -610.8846435546875, 'logps/rejected': -371.4034423828125, 'logits/chosen': 1.6699037551879883, 'logits/rejected': 2.5323216915130615, 'epoch': 0.01}
# {'loss': 0.7304, 'grad_norm': 142.03424072265625, 'learning_rate': 3.6e-05, 'rewards/chosen': -0.28408870100975037, 'rewards/rejected': -0.4655296504497528, 'rewards/accuracies': 0.375, 'rewards/margins': 0.18144091963768005, 'logps/chosen': -556.4839477539062, 'logps/rejected': -390.244873046875, 'logits/chosen': 1.896923542022705, 'logits/rejected': 3.868645191192627, 'epoch': 0.01}
# {'loss': 1.1982, 'grad_norm': 218.55836486816406, 'learning_rate': 3.65e-05, 'rewards/chosen': -0.808195948600769, 'rewards/rejected': -0.08844757080078125, 'rewards/accuracies': 0.125, 'rewards/margins': -0.7197483777999878, 'logps/chosen': -451.08514404296875, 'logps/rejected': -539.9546508789062, 'logits/chosen': 4.004977703094482, 'logits/rejected': 4.059045314788818, 'epoch': 0.01}
# {'loss': 0.8587, 'grad_norm': 163.46669006347656, 'learning_rate': 3.7e-05, 'rewards/chosen': -0.5876966714859009, 'rewards/rejected': -0.38942453265190125, 'rewards/accuracies': 0.25, 'rewards/margins': -0.19827216863632202, 'logps/chosen': -620.673828125, 'logps/rejected': -458.8020324707031, 'logits/chosen': 1.4995955228805542, 'logits/rejected': 1.306939721107483, 'epoch': 0.01}
# {'loss': 0.8173, 'grad_norm': 163.9337615966797, 'learning_rate': 3.7500000000000003e-05, 'rewards/chosen': -0.08861704170703888, 'rewards/rejected': -0.32099056243896484, 'rewards/accuracies': 0.625, 'rewards/margins': 0.23237356543540955, 'logps/chosen': -486.57501220703125, 'logps/rejected': -535.0120849609375, 'logits/chosen': 2.4714317321777344, 'logits/rejected': 2.863816261291504, 'epoch': 0.01}
# {'loss': 0.4427, 'grad_norm': 72.921875, 'learning_rate': 3.8e-05, 'rewards/chosen': 0.29861027002334595, 'rewards/rejected': -0.7757662534713745, 'rewards/accuracies': 0.75, 'rewards/margins': 1.0743764638900757, 'logps/chosen': -316.90533447265625, 'logps/rejected': -362.04180908203125, 'logits/chosen': 6.11234712600708, 'logits/rejected': 3.3042585849761963, 'epoch': 0.01}
# {'loss': 0.6019, 'grad_norm': 145.51007080078125, 'learning_rate': 3.85e-05, 'rewards/chosen': 0.22660192847251892, 'rewards/rejected': -0.17191755771636963, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3985194265842438, 'logps/chosen': -701.8330078125, 'logps/rejected': -576.6477661132812, 'logits/chosen': 3.802131414413452, 'logits/rejected': 2.843520164489746, 'epoch': 0.01}
# {'loss': 0.71, 'grad_norm': 151.2139892578125, 'learning_rate': 3.9000000000000006e-05, 'rewards/chosen': -0.3560603857040405, 'rewards/rejected': -0.5126413106918335, 'rewards/accuracies': 0.625, 'rewards/margins': 0.15658095479011536, 'logps/chosen': -727.9984741210938, 'logps/rejected': -470.27410888671875, 'logits/chosen': 2.057199716567993, 'logits/rejected': 0.9805071353912354, 'epoch': 0.01}
# {'loss': 0.9961, 'grad_norm': 168.36703491210938, 'learning_rate': 3.9500000000000005e-05, 'rewards/chosen': -0.42339468002319336, 'rewards/rejected': -0.09794417023658752, 'rewards/accuracies': 0.375, 'rewards/margins': -0.3254505395889282, 'logps/chosen': -433.5543212890625, 'logps/rejected': -377.47174072265625, 'logits/chosen': 3.534754753112793, 'logits/rejected': 4.38817024230957, 'epoch': 0.01}
# {'loss': 0.9832, 'grad_norm': 212.31658935546875, 'learning_rate': 4e-05, 'rewards/chosen': -0.49611738324165344, 'rewards/rejected': -0.2393895834684372, 'rewards/accuracies': 0.5, 'rewards/margins': -0.2567278742790222, 'logps/chosen': -415.94305419921875, 'logps/rejected': -551.7736206054688, 'logits/chosen': 1.1432926654815674, 'logits/rejected': 0.8888264894485474, 'epoch': 0.01}
# {'loss': 0.4005, 'grad_norm': 78.85738372802734, 'learning_rate': 4.05e-05, 'rewards/chosen': -0.128010094165802, 'rewards/rejected': -1.2643349170684814, 'rewards/accuracies': 0.75, 'rewards/margins': 1.1363248825073242, 'logps/chosen': -770.6754150390625, 'logps/rejected': -458.40509033203125, 'logits/chosen': 2.8196215629577637, 'logits/rejected': 1.777512550354004, 'epoch': 0.01}
# {'loss': 0.8412, 'grad_norm': 199.24478149414062, 'learning_rate': 4.1e-05, 'rewards/chosen': -0.002621598541736603, 'rewards/rejected': 0.007300183176994324, 'rewards/accuracies': 0.625, 'rewards/margins': -0.009921804070472717, 'logps/chosen': -420.16290283203125, 'logps/rejected': -447.2773132324219, 'logits/chosen': 1.8426300287246704, 'logits/rejected': 2.3808131217956543, 'epoch': 0.01}
# {'loss': 0.9606, 'grad_norm': 197.65806579589844, 'learning_rate': 4.15e-05, 'rewards/chosen': -0.4879515469074249, 'rewards/rejected': -0.11810265481472015, 'rewards/accuracies': 0.25, 'rewards/margins': -0.3698488473892212, 'logps/chosen': -489.4012145996094, 'logps/rejected': -563.9091796875, 'logits/chosen': 2.2462759017944336, 'logits/rejected': 2.958691120147705, 'epoch': 0.01}
# {'loss': 0.6435, 'grad_norm': 105.27262115478516, 'learning_rate': 4.2e-05, 'rewards/chosen': 0.11876021325588226, 'rewards/rejected': -0.15331053733825684, 'rewards/accuracies': 0.5, 'rewards/margins': 0.2720707654953003, 'logps/chosen': -445.8182373046875, 'logps/rejected': -401.82537841796875, 'logits/chosen': 4.6137003898620605, 'logits/rejected': 1.9301482439041138, 'epoch': 0.01}
# {'loss': 0.7883, 'grad_norm': 169.92190551757812, 'learning_rate': 4.25e-05, 'rewards/chosen': -0.09305009245872498, 'rewards/rejected': -0.11900673806667328, 'rewards/accuracies': 0.5, 'rewards/margins': 0.02595663070678711, 'logps/chosen': -630.9139404296875, 'logps/rejected': -460.76446533203125, 'logits/chosen': 2.1767144203186035, 'logits/rejected': 3.7491021156311035, 'epoch': 0.01}
# {'loss': 0.6931, 'grad_norm': 174.88357543945312, 'learning_rate': 4.3e-05, 'rewards/chosen': -0.09263419359922409, 'rewards/rejected': -0.6529502868652344, 'rewards/accuracies': 0.625, 'rewards/margins': 0.5603160858154297, 'logps/chosen': -662.3321533203125, 'logps/rejected': -600.67529296875, 'logits/chosen': 0.35257601737976074, 'logits/rejected': 1.8105274438858032, 'epoch': 0.01}
# {'loss': 0.6839, 'grad_norm': 91.04265594482422, 'learning_rate': 4.35e-05, 'rewards/chosen': -0.05417584627866745, 'rewards/rejected': -0.1455981731414795, 'rewards/accuracies': 0.625, 'rewards/margins': 0.09142231196165085, 'logps/chosen': -158.3822021484375, 'logps/rejected': -238.99754333496094, 'logits/chosen': 5.357690811157227, 'logits/rejected': 4.286694049835205, 'epoch': 0.01}
# {'loss': 0.9743, 'grad_norm': 178.95787048339844, 'learning_rate': 4.4000000000000006e-05, 'rewards/chosen': 0.05294466018676758, 'rewards/rejected': 0.42443257570266724, 'rewards/accuracies': 0.25, 'rewards/margins': -0.37148791551589966, 'logps/chosen': -463.2573547363281, 'logps/rejected': -372.5789794921875, 'logits/chosen': 2.6065304279327393, 'logits/rejected': 1.8690413236618042, 'epoch': 0.01}
# {'loss': 0.5731, 'grad_norm': 128.04371643066406, 'learning_rate': 4.4500000000000004e-05, 'rewards/chosen': 0.3211829364299774, 'rewards/rejected': -0.12800465524196625, 'rewards/accuracies': 0.625, 'rewards/margins': 0.44918757677078247, 'logps/chosen': -809.376708984375, 'logps/rejected': -463.1351318359375, 'logits/chosen': 1.9009909629821777, 'logits/rejected': 0.7847518920898438, 'epoch': 0.01}
# {'loss': 0.8275, 'grad_norm': 181.77239990234375, 'learning_rate': 4.5e-05, 'rewards/chosen': -0.33193284273147583, 'rewards/rejected': -0.20669832825660706, 'rewards/accuracies': 0.375, 'rewards/margins': -0.12523451447486877, 'logps/chosen': -630.25830078125, 'logps/rejected': -528.2894287109375, 'logits/chosen': 2.4604365825653076, 'logits/rejected': 4.206202030181885, 'epoch': 0.01}
# {'loss': 0.8462, 'grad_norm': 212.9813995361328, 'learning_rate': 4.55e-05, 'rewards/chosen': 0.25101107358932495, 'rewards/rejected': 0.2805120348930359, 'rewards/accuracies': 0.5, 'rewards/margins': -0.029500961303710938, 'logps/chosen': -621.1318969726562, 'logps/rejected': -443.4819641113281, 'logits/chosen': 0.38553670048713684, 'logits/rejected': 0.5067830085754395, 'epoch': 0.01}
# {'loss': 0.5494, 'grad_norm': 125.6280746459961, 'learning_rate': 4.600000000000001e-05, 'rewards/chosen': 0.4035297632217407, 'rewards/rejected': -0.2066497802734375, 'rewards/accuracies': 0.5, 'rewards/margins': 0.6101795434951782, 'logps/chosen': -497.5717468261719, 'logps/rejected': -359.302734375, 'logits/chosen': 2.098085880279541, 'logits/rejected': 2.048427104949951, 'epoch': 0.01}
# {'loss': 0.4252, 'grad_norm': 104.03579711914062, 'learning_rate': 4.6500000000000005e-05, 'rewards/chosen': 0.42343083024024963, 'rewards/rejected': -0.45477294921875, 'rewards/accuracies': 0.875, 'rewards/margins': 0.8782037496566772, 'logps/chosen': -526.8455200195312, 'logps/rejected': -486.7222900390625, 'logits/chosen': 2.431155204772949, 'logits/rejected': 3.424924373626709, 'epoch': 0.01}
# {'loss': 0.8521, 'grad_norm': 125.78450012207031, 'learning_rate': 4.7e-05, 'rewards/chosen': -0.07422105222940445, 'rewards/rejected': 0.048149317502975464, 'rewards/accuracies': 0.5, 'rewards/margins': -0.12237033247947693, 'logps/chosen': -404.11273193359375, 'logps/rejected': -443.5967712402344, 'logits/chosen': 3.2760000228881836, 'logits/rejected': 2.337149143218994, 'epoch': 0.01}
# {'loss': 0.6108, 'grad_norm': 113.183349609375, 'learning_rate': 4.75e-05, 'rewards/chosen': 0.24974286556243896, 'rewards/rejected': -0.08248543739318848, 'rewards/accuracies': 0.75, 'rewards/margins': 0.33222830295562744, 'logps/chosen': -414.3230285644531, 'logps/rejected': -276.4631042480469, 'logits/chosen': 5.415360927581787, 'logits/rejected': 5.34813117980957, 'epoch': 0.01}
# {'loss': 0.4135, 'grad_norm': 98.64376068115234, 'learning_rate': 4.8e-05, 'rewards/chosen': 0.5558420419692993, 'rewards/rejected': -0.6778795123100281, 'rewards/accuracies': 0.75, 'rewards/margins': 1.2337216138839722, 'logps/chosen': -482.211181640625, 'logps/rejected': -379.05340576171875, 'logits/chosen': 3.8920936584472656, 'logits/rejected': 3.6990275382995605, 'epoch': 0.01}
# {'loss': 0.9426, 'grad_norm': 143.8428955078125, 'learning_rate': 4.85e-05, 'rewards/chosen': 0.27108991146087646, 'rewards/rejected': 0.06408348679542542, 'rewards/accuracies': 0.5, 'rewards/margins': 0.20700643956661224, 'logps/chosen': -551.314208984375, 'logps/rejected': -461.06219482421875, 'logits/chosen': 2.7990899085998535, 'logits/rejected': 3.4020209312438965, 'epoch': 0.01}
# {'loss': 0.3381, 'grad_norm': 82.0374984741211, 'learning_rate': 4.9e-05, 'rewards/chosen': 0.7826347351074219, 'rewards/rejected': -0.40503624081611633, 'rewards/accuracies': 1.0, 'rewards/margins': 1.1876710653305054, 'logps/chosen': -735.2787475585938, 'logps/rejected': -666.5606079101562, 'logits/chosen': 2.1195547580718994, 'logits/rejected': 3.194880485534668, 'epoch': 0.01}
# {'loss': 0.4591, 'grad_norm': 128.013427734375, 'learning_rate': 4.9500000000000004e-05, 'rewards/chosen': 0.8201877474784851, 'rewards/rejected': -0.1700718104839325, 'rewards/accuracies': 0.75, 'rewards/margins': 0.9902596473693848, 'logps/chosen': -561.0718994140625, 'logps/rejected': -499.56048583984375, 'logits/chosen': 3.2009477615356445, 'logits/rejected': 4.185715675354004, 'epoch': 0.01}
# {'loss': 0.6865, 'grad_norm': 124.58006286621094, 'learning_rate': 5e-05, 'rewards/chosen': 0.36204859614372253, 'rewards/rejected': 0.24246034026145935, 'rewards/accuracies': 0.625, 'rewards/margins': 0.11958823353052139, 'logps/chosen': -371.601806640625, 'logps/rejected': -346.3244934082031, 'logits/chosen': 3.8705663681030273, 'logits/rejected': 3.3146450519561768, 'epoch': 0.01}
# {'loss': 0.5184, 'grad_norm': 102.99837493896484, 'learning_rate': 4.998766400914329e-05, 'rewards/chosen': 1.0005512237548828, 'rewards/rejected': 0.24021807312965393, 'rewards/accuracies': 0.75, 'rewards/margins': 0.7603330016136169, 'logps/chosen': -484.6672668457031, 'logps/rejected': -419.61383056640625, 'logits/chosen': 2.561091661453247, 'logits/rejected': 1.50819730758667, 'epoch': 0.01}
# {'loss': 0.5698, 'grad_norm': 89.50605773925781, 'learning_rate': 4.995066821070679e-05, 'rewards/chosen': 1.0783970355987549, 'rewards/rejected': 0.55690598487854, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5214910507202148, 'logps/chosen': -424.0435791015625, 'logps/rejected': -352.3719177246094, 'logits/chosen': 2.1806468963623047, 'logits/rejected': 3.2752928733825684, 'epoch': 0.01}
# {'loss': 0.6551, 'grad_norm': 128.4276123046875, 'learning_rate': 4.9889049115077005e-05, 'rewards/chosen': 0.589201033115387, 'rewards/rejected': 0.24727164208889008, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3419293463230133, 'logps/chosen': -603.59375, 'logps/rejected': -411.49810791015625, 'logits/chosen': 2.7839105129241943, 'logits/rejected': 2.1326651573181152, 'epoch': 0.01}
# {'loss': 0.8287, 'grad_norm': 103.06877899169922, 'learning_rate': 4.980286753286195e-05, 'rewards/chosen': 0.4832029640674591, 'rewards/rejected': 0.2647455036640167, 'rewards/accuracies': 0.625, 'rewards/margins': 0.21845743060112, 'logps/chosen': -376.4428405761719, 'logps/rejected': -356.9114685058594, 'logits/chosen': 2.117894411087036, 'logits/rejected': 2.153916120529175, 'epoch': 0.01}
# {'loss': 0.8502, 'grad_norm': 170.3799591064453, 'learning_rate': 4.9692208514878444e-05, 'rewards/chosen': 0.7967396974563599, 'rewards/rejected': 0.9234985113143921, 'rewards/accuracies': 0.625, 'rewards/margins': -0.12675872445106506, 'logps/chosen': -581.4754638671875, 'logps/rejected': -708.0618286132812, 'logits/chosen': 1.4906086921691895, 'logits/rejected': 2.278888702392578, 'epoch': 0.01}
# {'loss': 0.6413, 'grad_norm': 67.93293762207031, 'learning_rate': 4.9557181268217227e-05, 'rewards/chosen': 0.39469632506370544, 'rewards/rejected': -0.05562619864940643, 'rewards/accuracies': 0.75, 'rewards/margins': 0.4503225088119507, 'logps/chosen': -313.230224609375, 'logps/rejected': -300.936767578125, 'logits/chosen': 3.3144400119781494, 'logits/rejected': 3.154758930206299, 'epoch': 0.01}
# {'loss': 0.4951, 'grad_norm': 94.6489028930664, 'learning_rate': 4.939791904846869e-05, 'rewards/chosen': 0.4743230938911438, 'rewards/rejected': -0.22031088173389435, 'rewards/accuracies': 0.625, 'rewards/margins': 0.694633960723877, 'logps/chosen': -600.6305541992188, 'logps/rejected': -484.0391540527344, 'logits/chosen': 1.9631643295288086, 'logits/rejected': 3.2563698291778564, 'epoch': 0.01}
# {'loss': 0.7052, 'grad_norm': 143.96148681640625, 'learning_rate': 4.9214579028215776e-05, 'rewards/chosen': -0.19036808609962463, 'rewards/rejected': -0.3111020624637604, 'rewards/accuracies': 0.5, 'rewards/margins': 0.12073396146297455, 'logps/chosen': -378.1977233886719, 'logps/rejected': -248.2900390625, 'logits/chosen': 2.435520887374878, 'logits/rejected': 4.292829513549805, 'epoch': 0.01}
# {'loss': 0.6189, 'grad_norm': 104.68402099609375, 'learning_rate': 4.900734214192358e-05, 'rewards/chosen': 0.4275754690170288, 'rewards/rejected': -0.1313314288854599, 'rewards/accuracies': 0.5, 'rewards/margins': 0.5589069128036499, 'logps/chosen': -625.9879150390625, 'logps/rejected': -260.0923767089844, 'logits/chosen': 3.6211555004119873, 'logits/rejected': 5.418024063110352, 'epoch': 0.01}
# {'loss': 1.2656, 'grad_norm': 252.69998168945312, 'learning_rate': 4.877641290737884e-05, 'rewards/chosen': -0.6124032139778137, 'rewards/rejected': -0.2585793137550354, 'rewards/accuracies': 0.375, 'rewards/margins': -0.3538239002227783, 'logps/chosen': -620.1351318359375, 'logps/rejected': -834.2801513671875, 'logits/chosen': 2.175670862197876, 'logits/rejected': 3.1282899379730225, 'epoch': 0.01}
# {'loss': 0.7101, 'grad_norm': 145.2205352783203, 'learning_rate': 4.852201922385564e-05, 'rewards/chosen': 0.04153279960155487, 'rewards/rejected': -0.005020003765821457, 'rewards/accuracies': 0.5, 'rewards/margins': 0.04655279219150543, 'logps/chosen': -236.27426147460938, 'logps/rejected': -371.9464111328125, 'logits/chosen': 3.352591037750244, 'logits/rejected': 4.531917095184326, 'epoch': 0.01}
# {'loss': 0.646, 'grad_norm': 85.2843017578125, 'learning_rate': 4.8244412147206284e-05, 'rewards/chosen': 0.6616443395614624, 'rewards/rejected': 0.36491307616233826, 'rewards/accuracies': 0.625, 'rewards/margins': 0.29673126339912415, 'logps/chosen': -521.8723754882812, 'logps/rejected': -288.6007995605469, 'logits/chosen': 2.1217637062072754, 'logits/rejected': 2.239312171936035, 'epoch': 0.01}
# {'loss': 0.6129, 'grad_norm': 110.33992004394531, 'learning_rate': 4.794386564209953e-05, 'rewards/chosen': 0.20250016450881958, 'rewards/rejected': -0.29723119735717773, 'rewards/accuracies': 0.875, 'rewards/margins': 0.4997313916683197, 'logps/chosen': -353.7760009765625, 'logps/rejected': -573.2705078125, 'logits/chosen': 4.622374534606934, 'logits/rejected': 2.217613697052002, 'epoch': 0.01}
# {'loss': 0.7254, 'grad_norm': 156.2260284423828, 'learning_rate': 4.762067631165049e-05, 'rewards/chosen': -0.2521217465400696, 'rewards/rejected': -0.5414429903030396, 'rewards/accuracies': 0.5, 'rewards/margins': 0.28932124376296997, 'logps/chosen': -347.1229553222656, 'logps/rejected': -434.7572937011719, 'logits/chosen': 3.7958288192749023, 'logits/rejected': 3.9392709732055664, 'epoch': 0.01}
# {'loss': 0.7101, 'grad_norm': 164.09239196777344, 'learning_rate': 4.72751631047092e-05, 'rewards/chosen': 0.014578238129615784, 'rewards/rejected': -0.13546258211135864, 'rewards/accuracies': 0.625, 'rewards/margins': 0.15004082024097443, 'logps/chosen': -644.1517333984375, 'logps/rejected': -434.86822509765625, 'logits/chosen': 1.579943299293518, 'logits/rejected': 3.3398020267486572, 'epoch': 0.01}
# {'loss': 0.4718, 'grad_norm': 65.06320190429688, 'learning_rate': 4.690766700109659e-05, 'rewards/chosen': 0.6750236749649048, 'rewards/rejected': 0.09587433934211731, 'rewards/accuracies': 1.0, 'rewards/margins': 0.5791492462158203, 'logps/chosen': -367.3343811035156, 'logps/rejected': -198.7247772216797, 'logits/chosen': 2.5734171867370605, 'logits/rejected': 2.352191209793091, 'epoch': 0.01}
# {'loss': 1.0488, 'grad_norm': 148.24267578125, 'learning_rate': 4.65185506750986e-05, 'rewards/chosen': 0.21469393372535706, 'rewards/rejected': 0.3363227844238281, 'rewards/accuracies': 0.25, 'rewards/margins': -0.12162882089614868, 'logps/chosen': -485.58746337890625, 'logps/rejected': -489.53802490234375, 'logits/chosen': 1.9298462867736816, 'logits/rejected': 2.9393436908721924, 'epoch': 0.02}
# {'loss': 0.8045, 'grad_norm': 114.610595703125, 'learning_rate': 4.610819813755038e-05, 'rewards/chosen': -0.08989819884300232, 'rewards/rejected': -0.5206941366195679, 'rewards/accuracies': 0.375, 'rewards/margins': 0.43079590797424316, 'logps/chosen': -404.7342529296875, 'logps/rejected': -389.43865966796875, 'logits/chosen': 2.3045899868011475, 'logits/rejected': 1.8277883529663086, 'epoch': 0.02}
# {'loss': 0.795, 'grad_norm': 125.08170318603516, 'learning_rate': 4.567701435686404e-05, 'rewards/chosen': -0.2714099884033203, 'rewards/rejected': -0.35086119174957275, 'rewards/accuracies': 0.5, 'rewards/margins': 0.07945118844509125, 'logps/chosen': -394.7124938964844, 'logps/rejected': -401.7168273925781, 'logits/chosen': 1.801866054534912, 'logits/rejected': 3.222130298614502, 'epoch': 0.02}
# {'loss': 0.8417, 'grad_norm': 153.44696044921875, 'learning_rate': 4.522542485937369e-05, 'rewards/chosen': -0.2466207593679428, 'rewards/rejected': -0.24514609575271606, 'rewards/accuracies': 0.5, 'rewards/margins': -0.0014746785163879395, 'logps/chosen': -473.1895446777344, 'logps/rejected': -328.541015625, 'logits/chosen': 3.0437188148498535, 'logits/rejected': 3.555816173553467, 'epoch': 0.02}
# {'loss': 0.6438, 'grad_norm': 114.73551177978516, 'learning_rate': 4.4753875309392266e-05, 'rewards/chosen': 0.48742905259132385, 'rewards/rejected': -0.34496399760246277, 'rewards/accuracies': 0.875, 'rewards/margins': 0.8323930501937866, 'logps/chosen': -557.4784545898438, 'logps/rejected': -519.6460571289062, 'logits/chosen': 0.2533266246318817, 'logits/rejected': 0.4168901741504669, 'epoch': 0.02}
# ...
# {'loss': 1.0313, 'grad_norm': 129.32098388671875, 'learning_rate': 1.5071302734130489e-05, 'rewards/chosen': 0.24794264137744904, 'rewards/rejected': 0.5652647018432617, 'rewards/accuracies': 0.375, 'rewards/margins': -0.3173220455646515, 'logps/chosen': -340.4024658203125, 'logps/rejected': -390.2109680175781, 'logits/chosen': 2.398715019226074, 'logits/rejected': 2.3184313774108887, 'epoch': 0.02}
# {'loss': 0.8258, 'grad_norm': 119.73971557617188, 'learning_rate': 1.4355517710873184e-05, 'rewards/chosen': 0.07307976484298706, 'rewards/rejected': -0.0411112904548645, 'rewards/accuracies': 0.375, 'rewards/margins': 0.11419105529785156, 'logps/chosen': -337.8180847167969, 'logps/rejected': -344.4986267089844, 'logits/chosen': 4.594573974609375, 'logits/rejected': 3.027970314025879, 'epoch': 0.02}
# {'loss': 0.6229, 'grad_norm': 119.27445983886719, 'learning_rate': 1.3650237506511331e-05, 'rewards/chosen': 1.1500158309936523, 'rewards/rejected': 0.5631687641143799, 'rewards/accuracies': 0.625, 'rewards/margins': 0.586847186088562, 'logps/chosen': -393.1388854980469, 'logps/rejected': -351.6712646484375, 'logits/chosen': 2.1338295936584473, 'logits/rejected': 2.1827499866485596, 'epoch': 0.02}
# {'loss': 1.1108, 'grad_norm': 171.54110717773438, 'learning_rate': 1.2956158147457115e-05, 'rewards/chosen': 0.396938681602478, 'rewards/rejected': 0.7910621166229248, 'rewards/accuracies': 0.375, 'rewards/margins': -0.3941234052181244, 'logps/chosen': -699.843017578125, 'logps/rejected': -530.7605590820312, 'logits/chosen': 1.0073285102844238, 'logits/rejected': 0.7898927927017212, 'epoch': 0.02}
# {'loss': 1.1599, 'grad_norm': 216.81256103515625, 'learning_rate': 1.2273964606240718e-05, 'rewards/chosen': 0.36092251539230347, 'rewards/rejected': 0.8070489168167114, 'rewards/accuracies': 0.375, 'rewards/margins': -0.4461263418197632, 'logps/chosen': -673.1258544921875, 'logps/rejected': -622.2850341796875, 'logits/chosen': 1.4626469612121582, 'logits/rejected': 2.822603702545166, 'epoch': 0.02}
# {'loss': 1.3729, 'grad_norm': 143.512451171875, 'learning_rate': 1.1604330125525079e-05, 'rewards/chosen': 0.3476470410823822, 'rewards/rejected': 0.6630487442016602, 'rewards/accuracies': 0.5, 'rewards/margins': -0.31540167331695557, 'logps/chosen': -358.943603515625, 'logps/rejected': -524.7296142578125, 'logits/chosen': 2.61283016204834, 'logits/rejected': 2.86200213432312, 'epoch': 0.02}
# {'loss': 0.6334, 'grad_norm': 99.85161590576172, 'learning_rate': 1.0947915553696742e-05, 'rewards/chosen': 0.2783079445362091, 'rewards/rejected': -0.18075862526893616, 'rewards/accuracies': 0.5, 'rewards/margins': 0.45906656980514526, 'logps/chosen': -441.1377868652344, 'logps/rejected': -344.37139892578125, 'logits/chosen': 3.0068392753601074, 'logits/rejected': 3.1556358337402344, 'epoch': 0.02}
# {'loss': 0.7475, 'grad_norm': 174.2250518798828, 'learning_rate': 1.0305368692688174e-05, 'rewards/chosen': 0.36533641815185547, 'rewards/rejected': 0.0822484940290451, 'rewards/accuracies': 0.5, 'rewards/margins': 0.28308790922164917, 'logps/chosen': -685.1041870117188, 'logps/rejected': -466.9505615234375, 'logits/chosen': 0.37490272521972656, 'logits/rejected': 2.257577896118164, 'epoch': 0.02}
# {'loss': 0.4894, 'grad_norm': 103.94873809814453, 'learning_rate': 9.677323658675594e-06, 'rewards/chosen': 0.8145912289619446, 'rewards/rejected': -0.1908133625984192, 'rewards/accuracies': 0.75, 'rewards/margins': 1.0054045915603638, 'logps/chosen': -513.9981689453125, 'logps/rejected': -434.71136474609375, 'logits/chosen': 1.8740904331207275, 'logits/rejected': 2.5823521614074707, 'epoch': 0.02}
# {'loss': 0.8655, 'grad_norm': 114.69786834716797, 'learning_rate': 9.064400256282757e-06, 'rewards/chosen': -0.2912539541721344, 'rewards/rejected': -0.11853857338428497, 'rewards/accuracies': 0.375, 'rewards/margins': -0.17271539568901062, 'logps/chosen': -310.6883239746094, 'logps/rejected': -392.20123291015625, 'logits/chosen': 2.226539373397827, 'logits/rejected': 2.0522711277008057, 'epoch': 0.02}
# {'loss': 0.5016, 'grad_norm': 121.72145080566406, 'learning_rate': 8.467203366908707e-06, 'rewards/chosen': 0.14796949923038483, 'rewards/rejected': -0.9481160044670105, 'rewards/accuracies': 0.75, 'rewards/margins': 1.096085548400879, 'logps/chosen': -475.98345947265625, 'logps/rejected': -416.53668212890625, 'logits/chosen': 2.747817039489746, 'logits/rejected': 1.89505934715271, 'epoch': 0.02}
# {'loss': 0.6687, 'grad_norm': 100.97047424316406, 'learning_rate': 7.886322351782783e-06, 'rewards/chosen': -0.2833464443683624, 'rewards/rejected': -0.7913135290145874, 'rewards/accuracies': 0.375, 'rewards/margins': 0.5079671144485474, 'logps/chosen': -220.04751586914062, 'logps/rejected': -445.6825256347656, 'logits/chosen': 4.015658855438232, 'logits/rejected': 1.927359700202942, 'epoch': 0.02}
# {'loss': 0.8639, 'grad_norm': 156.79917907714844, 'learning_rate': 7.3223304703363135e-06, 'rewards/chosen': 0.2722145915031433, 'rewards/rejected': 0.21582955121994019, 'rewards/accuracies': 0.5, 'rewards/margins': 0.05638507008552551, 'logps/chosen': -549.2344970703125, 'logps/rejected': -333.5962219238281, 'logits/chosen': 1.288177251815796, 'logits/rejected': 3.626455783843994, 'epoch': 0.02}
# {'loss': 0.8614, 'grad_norm': 145.08795166015625, 'learning_rate': 6.775784314464717e-06, 'rewards/chosen': -0.2621750831604004, 'rewards/rejected': -0.061673738062381744, 'rewards/accuracies': 0.375, 'rewards/margins': -0.20050135254859924, 'logps/chosen': -471.40167236328125, 'logps/rejected': -425.1948547363281, 'logits/chosen': 2.903027296066284, 'logits/rejected': 3.905550956726074, 'epoch': 0.02}
# {'loss': 0.7883, 'grad_norm': 136.02378845214844, 'learning_rate': 6.247223259238513e-06, 'rewards/chosen': 0.32645389437675476, 'rewards/rejected': 0.12009916454553604, 'rewards/accuracies': 0.625, 'rewards/margins': 0.20635469257831573, 'logps/chosen': -654.5768432617188, 'logps/rejected': -404.8094787597656, 'logits/chosen': 0.12057068943977356, 'logits/rejected': 1.295148491859436, 'epoch': 0.02}
# {'loss': 0.9321, 'grad_norm': 163.01234436035156, 'learning_rate': 5.737168930605272e-06, 'rewards/chosen': -0.33154869079589844, 'rewards/rejected': -0.3027054965496063, 'rewards/accuracies': 0.625, 'rewards/margins': -0.02884317934513092, 'logps/chosen': -498.8823547363281, 'logps/rejected': -520.7366943359375, 'logits/chosen': 2.7884104251861572, 'logits/rejected': 3.6861228942871094, 'epoch': 0.02}
# {'loss': 0.6529, 'grad_norm': 127.30559539794922, 'learning_rate': 5.24612469060774e-06, 'rewards/chosen': 0.7517085075378418, 'rewards/rejected': 0.05719022452831268, 'rewards/accuracies': 0.5, 'rewards/margins': 0.6945183277130127, 'logps/chosen': -731.7498168945312, 'logps/rejected': -517.1458129882812, 'logits/chosen': 1.2033135890960693, 'logits/rejected': 0.979510486125946, 'epoch': 0.02}
# {'loss': 0.882, 'grad_norm': 128.93893432617188, 'learning_rate': 4.7745751406263165e-06, 'rewards/chosen': 0.16435746848583221, 'rewards/rejected': 0.28702089190483093, 'rewards/accuracies': 0.5, 'rewards/margins': -0.12266340851783752, 'logps/chosen': -448.1104736328125, 'logps/rejected': -326.728271484375, 'logits/chosen': 1.1146990060806274, 'logits/rejected': 1.2701507806777954, 'epoch': 0.02}
# {'loss': 0.97, 'grad_norm': 193.4005584716797, 'learning_rate': 4.322985643135952e-06, 'rewards/chosen': -0.07381400465965271, 'rewards/rejected': 0.044147104024887085, 'rewards/accuracies': 0.5, 'rewards/margins': -0.11796113848686218, 'logps/chosen': -488.101806640625, 'logps/rejected': -483.03924560546875, 'logits/chosen': 1.6112723350524902, 'logits/rejected': 1.506040096282959, 'epoch': 0.02}
# {'loss': 0.4115, 'grad_norm': 102.46842193603516, 'learning_rate': 3.891801862449629e-06, 'rewards/chosen': 0.6793498992919922, 'rewards/rejected': -0.42244720458984375, 'rewards/accuracies': 0.75, 'rewards/margins': 1.101797103881836, 'logps/chosen': -498.12225341796875, 'logps/rejected': -461.735595703125, 'logits/chosen': 3.8172521591186523, 'logits/rejected': 4.539002895355225, 'epoch': 0.02}
# {'loss': 0.7404, 'grad_norm': 159.42953491210938, 'learning_rate': 3.4814493249014116e-06, 'rewards/chosen': 0.6230415105819702, 'rewards/rejected': -0.08790474385023117, 'rewards/accuracies': 0.5, 'rewards/margins': 0.710946261882782, 'logps/chosen': -696.8220825195312, 'logps/rejected': -468.0308837890625, 'logits/chosen': 2.314931631088257, 'logits/rejected': 1.6479887962341309, 'epoch': 0.02}
# {'loss': 0.8209, 'grad_norm': 145.05029296875, 'learning_rate': 3.0923329989034132e-06, 'rewards/chosen': 0.21881721913814545, 'rewards/rejected': 0.041019514203071594, 'rewards/accuracies': 0.5, 'rewards/margins': 0.17779767513275146, 'logps/chosen': -706.3023681640625, 'logps/rejected': -524.3208618164062, 'logits/chosen': 1.6891311407089233, 'logits/rejected': 1.9582544565200806, 'epoch': 0.02}
# {'loss': 0.9394, 'grad_norm': 147.32347106933594, 'learning_rate': 2.7248368952908053e-06, 'rewards/chosen': -0.3648608326911926, 'rewards/rejected': -0.12660132348537445, 'rewards/accuracies': 0.375, 'rewards/margins': -0.23825953900814056, 'logps/chosen': -422.9187927246094, 'logps/rejected': -381.3711853027344, 'logits/chosen': 2.68428897857666, 'logits/rejected': 1.4330813884735107, 'epoch': 0.02}
# {'loss': 0.7089, 'grad_norm': 125.4704360961914, 'learning_rate': 2.379323688349516e-06, 'rewards/chosen': 0.17135310173034668, 'rewards/rejected': -0.24314060807228088, 'rewards/accuracies': 0.5, 'rewards/margins': 0.4144936501979828, 'logps/chosen': -504.83544921875, 'logps/rejected': -367.4739685058594, 'logits/chosen': 4.0750298500061035, 'logits/rejected': 3.10686993598938, 'epoch': 0.02}
# {'loss': 0.7132, 'grad_norm': 123.08245086669922, 'learning_rate': 2.0561343579004715e-06, 'rewards/chosen': -0.32936668395996094, 'rewards/rejected': -0.7313582897186279, 'rewards/accuracies': 0.5, 'rewards/margins': 0.401991605758667, 'logps/chosen': -487.23394775390625, 'logps/rejected': -321.61041259765625, 'logits/chosen': 3.2390475273132324, 'logits/rejected': 4.435794830322266, 'epoch': 0.02}
# {'loss': 0.8642, 'grad_norm': 157.94625854492188, 'learning_rate': 1.7555878527937164e-06, 'rewards/chosen': 0.12412790954113007, 'rewards/rejected': 0.19154207408428192, 'rewards/accuracies': 0.5, 'rewards/margins': -0.06741416454315186, 'logps/chosen': -539.468017578125, 'logps/rejected': -567.2691650390625, 'logits/chosen': 1.433645248413086, 'logits/rejected': 3.7213425636291504, 'epoch': 0.02}
# {'loss': 0.6193, 'grad_norm': 92.55860900878906, 'learning_rate': 1.4779807761443636e-06, 'rewards/chosen': 0.5175499320030212, 'rewards/rejected': -0.12324026972055435, 'rewards/accuracies': 0.75, 'rewards/margins': 0.6407901644706726, 'logps/chosen': -579.92724609375, 'logps/rejected': -461.1845703125, 'logits/chosen': 1.6645290851593018, 'logits/rejected': 3.1279144287109375, 'epoch': 0.02}
# {'loss': 0.4586, 'grad_norm': 111.56356811523438, 'learning_rate': 1.2235870926211619e-06, 'rewards/chosen': 0.7876842617988586, 'rewards/rejected': -0.27768000960350037, 'rewards/accuracies': 0.75, 'rewards/margins': 1.0653643608093262, 'logps/chosen': -575.5485229492188, 'logps/rejected': -402.58868408203125, 'logits/chosen': 0.9676183462142944, 'logits/rejected': 1.4697928428649902, 'epoch': 0.02}
# {'loss': 0.5795, 'grad_norm': 138.84036254882812, 'learning_rate': 9.926578580764234e-07, 'rewards/chosen': 0.10222090780735016, 'rewards/rejected': -0.5633233189582825, 'rewards/accuracies': 0.75, 'rewards/margins': 0.6655442118644714, 'logps/chosen': -484.0947265625, 'logps/rejected': -553.6055908203125, 'logits/chosen': 1.3180214166641235, 'logits/rejected': 1.0504330396652222, 'epoch': 0.02}
# {'loss': 0.46, 'grad_norm': 123.05261993408203, 'learning_rate': 7.854209717842231e-07, 'rewards/chosen': 0.7588852643966675, 'rewards/rejected': -1.0896514654159546, 'rewards/accuracies': 0.75, 'rewards/margins': 1.8485366106033325, 'logps/chosen': -642.4677124023438, 'logps/rejected': -767.8817749023438, 'logits/chosen': 1.912475347518921, 'logits/rejected': 2.9922869205474854, 'epoch': 0.02}
# {'loss': 1.0121, 'grad_norm': 125.90940856933594, 'learning_rate': 6.020809515313142e-07, 'rewards/chosen': 0.46703749895095825, 'rewards/rejected': 0.8528107404708862, 'rewards/accuracies': 0.25, 'rewards/margins': -0.3857731819152832, 'logps/chosen': -447.5103454589844, 'logps/rejected': -385.7139892578125, 'logits/chosen': 2.9238901138305664, 'logits/rejected': 2.2169785499572754, 'epoch': 0.02}
# {'loss': 0.5449, 'grad_norm': 74.36082458496094, 'learning_rate': 4.4281873178278475e-07, 'rewards/chosen': 0.5436196327209473, 'rewards/rejected': -0.045403677970170975, 'rewards/accuracies': 0.625, 'rewards/margins': 0.5890233516693115, 'logps/chosen': -475.6197814941406, 'logps/rejected': -226.6075439453125, 'logits/chosen': 2.320542335510254, 'logits/rejected': 3.4834070205688477, 'epoch': 0.02}
# {'loss': 0.497, 'grad_norm': 78.52208709716797, 'learning_rate': 3.077914851215585e-07, 'rewards/chosen': 0.7412976026535034, 'rewards/rejected': -0.2616152763366699, 'rewards/accuracies': 0.625, 'rewards/margins': 1.002912998199463, 'logps/chosen': -477.0668640136719, 'logps/rejected': -240.09304809570312, 'logits/chosen': 0.5814720392227173, 'logits/rejected': 2.7159035205841064, 'epoch': 0.03}
# {'loss': 0.5903, 'grad_norm': 106.65252685546875, 'learning_rate': 1.9713246713805588e-07, 'rewards/chosen': 0.21610300242900848, 'rewards/rejected': -0.09135057032108307, 'rewards/accuracies': 0.75, 'rewards/margins': 0.30745357275009155, 'logps/chosen': -557.1514892578125, 'logps/rejected': -412.22222900390625, 'logits/chosen': 1.2920252084732056, 'logits/rejected': 2.0618903636932373, 'epoch': 0.03}
# {'loss': 0.7292, 'grad_norm': 153.130126953125, 'learning_rate': 1.109508849230001e-07, 'rewards/chosen': 0.4540640413761139, 'rewards/rejected': 0.2003810703754425, 'rewards/accuracies': 0.5, 'rewards/margins': 0.2536829113960266, 'logps/chosen': -685.4880981445312, 'logps/rejected': -706.2471313476562, 'logits/chosen': 1.9852070808410645, 'logits/rejected': 4.197325229644775, 'epoch': 0.03}
# {'loss': 0.7125, 'grad_norm': 162.2511749267578, 'learning_rate': 4.9331789293211026e-08, 'rewards/chosen': 0.4468922019004822, 'rewards/rejected': -0.3001209497451782, 'rewards/accuracies': 0.75, 'rewards/margins': 0.7470130920410156, 'logps/chosen': -812.60546875, 'logps/rejected': -854.272216796875, 'logits/chosen': 0.8454468846321106, 'logits/rejected': 0.3295768201351166, 'epoch': 0.03}
# {'loss': 0.5917, 'grad_norm': 109.9596176147461, 'learning_rate': 1.233599085671e-08, 'rewards/chosen': -0.025163456797599792, 'rewards/rejected': -0.3449207544326782, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3197573125362396, 'logps/chosen': -352.63763427734375, 'logps/rejected': -322.31463623046875, 'logits/chosen': 3.3585281372070312, 'logits/rejected': 2.550936222076416, 'epoch': 0.03}
# {'loss': 0.5725, 'grad_norm': 82.5427017211914, 'learning_rate': 0.0, 'rewards/chosen': 0.5685780048370361, 'rewards/rejected': -0.16215480864048004, 'rewards/accuracies': 0.625, 'rewards/margins': 0.7307327389717102, 'logps/chosen': -444.068115234375, 'logps/rejected': -261.3880920410156, 'logits/chosen': 2.3969645500183105, 'logits/rejected': 1.6590226888656616, 'epoch': 0.03}
# {'train_runtime': 974.7338, 'train_samples_per_second': 1.641, 'train_steps_per_second': 0.205, 'train_loss': 0.7230158969759941, 'epoch': 0.03}
# TrainOutput(global_step=200, training_loss=0.7230158969759941, metrics={'train_runtime': 974.7338, 'train_samples_per_second': 1.641, 'train_steps_per_second': 0.205, 'total_flos': 0.0, 'train_loss': 0.7230158969759941, 'epoch': 0.025749967812540235})

# %%
# Save the model
trainer.save_model(f"./{finetune_name}")

# Save to the huggingface hub if login (HF_TOKEN is set)
if os.getenv("HF_TOKEN"):
    trainer.push_to_hub(tags=finetune_tags)
# Out:
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/6.07k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/538M [00:00<?, ?B/s]

# %% [markdown]
# ## 💐 You're done!
#
# This notebook provided a step-by-step guide to fine-tuning the `HuggingFaceTB/SmolLM2-135M` model using the `DPOTrainer`. By following these steps, you can adapt the model to perform specific tasks more effectively. If you want to carry on working on this course, here are steps you could try out:
#
# - Try this notebook on a harder difficulty
# - Review a colleagues PR
# - Improve the course material via an Issue or PR.
