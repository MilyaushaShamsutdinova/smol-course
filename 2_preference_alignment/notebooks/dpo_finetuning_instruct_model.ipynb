# %% [markdown]
# # Preference Alignment with Direct Preference Optimization (DPO)
#
# This notebook will guide you through the process of fine-tuning a language model using Direct Preference Optimization (DPO). We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#      <h2 style='margin: 0;color:blue'>Exercise: Aligning SmolLM2 with DPOTrainer</h2>
#      <p>Take a dataset from the Hugging Face hub and align a model on it. </p>
#      <p><b>Difficulty Levels</b></p>
#      <p>🐢 Use the `trl-lib/ultrafeedback_binarized` dataset</p>
#      <p>🐕 Try out the `argilla/ultrafeedback-binarized-preferences` dataset</p>
#      <p>🦁 Select a dataset that relates to a real-world use case you’re interested in, or use the model you trained in
#         <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
# Install the requirements in Google Colab
# !pip install transformers datasets trl huggingface_hub

# Authenticate to Hugging Face

from huggingface_hub import login
from dotenv import load_dotenv
import os

load_dotenv()

login(os.getenv("HF_TOKEN"))

# for convenience you can create an environment variable containing your hub token as HF_TOKEN
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Import libraries

# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
from trl import DPOTrainer, DPOConfig

# %% [markdown]
# ## Format dataset

# %%
# Load dataset
ds = load_dataset(path="trl-lib/ultrafeedback_binarized", split="train")

# %%
ds
# Out:
# Dataset({
#     features: ['chosen', 'rejected', 'score_chosen', 'score_rejected'],
#     num_rows: 62135
# })

# %%
ds[0]
# Out:
# {'chosen': [{'content': 'Use the pygame library to write a version of the classic game Snake, with a unique twist',
#    'role': 'user'},
#   {'content': "Sure, I'd be happy to help you write a version of the classic game Snake using the pygame library! Here's a basic outline of how we can approach this:\n\n1. First, we'll need to set up the game display and create a game object that we can use to handle the game's state.\n2. Next, we'll create the game's grid, which will be used to represent the game board. We'll need to define the size of the grid and the spaces within it.\n3. After that, we'll create the snake object, which will be used to represent the player's movement. We'll need to define the size of the snake and the speed at which it moves.\n4. We'll also need to create a food object, which will be used to represent the food that the player must collect to score points. We'll need to define the location of the food and the speed at which it moves.\n5. Once we have these objects set up, we can start handling the game's logic. We'll need to define the rules for the player's movements, such as how the player can move the snake and how the snake will grow as the player collects more food.\n6. We'll also need to add collisions detection to the game, so that the snake and the food can collide with each other.\n7. Finally, we'll need to add a user interface to the game, such as a menu and a scoreboard.\n\nNow, as for the unique twist, we could add a few features to make the game more interesting. For example, we could add power-ups that give the player special abilities, such as the ability to grow the snake faster or to change its direction. We could also add obstacles, such as walls or pits, that the player must avoid.\n\nHere's some sample code to get us started:\n```\nimport pygame\n\n# Initialize pygame\npygame.init()\n\n# Set up the game display\nwidth = 800\nheight = 600\nscreen = pygame.display.set_mode((width, height))\n\n# Define the colors\nWHITE = (255, 255, 255)\nBLACK = (0, 0, 0)\nGREEN = (0, 255, 0)\n\n# Define the game objects\nsnake = pygame.Rect(50, 50, 10, 10)\nfood = pygame.Rect(100, 100, 10, 10)\n\n# Define the game logic\ndef update_snake():\n    # Get the mouse position\n    mouse_pos = pygame.mouse.get_pos()\n\n    # Move the snake based on the mouse position\n    if mouse_pos[0] > snake.x:\n        snake.x += 10\n    elif mouse_pos[0] < snake.x:\n        snake.x -= 10\n    elif mouse_pos[1] > snake.y:\n        snake.y += 10\n    elif mouse_pos[1] < snake.y:\n        snake.y -= 10\n\n    # Update the snake's size\n    if snake.x == food.x and snake.y == food.y:\n        snake.width += 10\n        snake.height += 10\n\n# Define the game loop\ndef game_loop():\n    # Clear the screen\n    screen.fill(BLACK)\n\n    # Update the game objects\n    update_snake()\n\n    # Draw the game objects\n    screen.fill(WHITE)\n    screen.draw.rect(snake, GREEN)\n    screen.draw.rect(food, BLACK)\n\n    # Update the display\n    pygame.display.flip()\n\n# Start the game loop\ngame_loop()\n\n# Run the game\nwhile True:\n    for event in pygame.event.get():\n        if event.type == pygame.QUIT:\n            pygame.quit()\n            break\n\n    pygame.time.Clock().tick(60)\n```\nThis code sets up a basic game display, defines the snake and food objects, and updates the game state based on the player's movements. We've also added a simple user interface and some basic collision detection.\n\nAs for the unique twist, we could add a few features to make the game",
#    'role': 'assistant'}],
#  'rejected': [{'content': 'Use the pygame library to write a version of the classic game Snake, with a unique twist',
#    'role': 'user'},
#   {'content': 'Sure, here\'s an example of how to write a version of Snake game with a unique twist using the Pygame library:\n```python\nimport pygame\n\nclass SnakeGame:\n    def __init__(self, game_width, game_height):\n        pygame.init()\n        screen = pygame.display.set_mode((game_width, game_height))\n        pygame.display.set_caption("Snake Game")\n        self.speed = 5  # Speed of the snake\n        self.food_speed = 1  # Speed of the food\n        self.direction = 0  # Initial direction of the snake\n        self.snakelen = 0  # Length of the snake\n        self.food = pygame.image.load("snake_food.png")\n        self.head = pygame.image.load("snake_head.png")\n        self.tail = pygame.image.load("snake_tail.png")\n        self.game Quint()\n    def Quint(self):\n        for i in range(50):\n            pygame.draw.line(screen, (180, 100, 220), (0, 0, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 0, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 50, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 50, 300), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 80, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (50, 80, 300), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 50, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 50, 300), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 80, 200), 2)\n            pygame.draw.line(screen, (180, 100, 220), (0, 80, 300), 2)\n            pygame.display.flip()\n        self.game.run()\n    def run(self):\n        while True:\n            for event in pygame.event. pygame.KEYDOWN:\n                if event.key == pygame.K_LEFT:\n                    self.direction = -1\n                if event.key == pygame.K_RIGHT:\n                    self.direction = 1\n            self.snakelen += 1\n            if self.snakelen == 0:\n                self.snakelen = 10\n            if self.snakelen > 20:\n                self.snakelen = 20\n            self.gameQuint()\n            self.foodCrossing()\n            self.headRun()\n            pygame.display.update()\ngame = SnakeGame(800, 600)\ngame.run()\n```\nIn this game, the snake moves with a constant speed, but the direction of the snake can be controlled by the user using the left and right arrow keys. The snake grows in length every 10 segments, and when it reaches a certain length, it resets to 10 segments. The food moves fast and randomly crosses the screen, and the snake can eat it by colliding with it. The snake\'s head and tail move independently of each other. The game ends when the snake dies or reaches the end of the screen.',
#    'role': 'assistant'}],
#  'score_chosen': 6.0,
#  'score_rejected': 4.0}

# %% [markdown]
# ## Select the model
#
# We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; width:80%; color:black'>
#      <p>🦁 change the model to the path or repo id of the model you trained in <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
model_name = "HuggingFaceTB/SmolLM2-135M-Instruct"  # fine tune on instruct model

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
device
# Out:
# 'cuda'

# %%
# Model to fine-tune
model = AutoModelForCausalLM.from_pretrained(
    pretrained_model_name_or_path=model_name,
    torch_dtype=torch.float32,
).to(device)
model.config.use_cache = False
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# Set our name for the finetune to be saved &/ uploaded to
finetune_name = "SmolLM2-DPO-FT-Instruct"
finetune_tags = ["smol-course", "DPO"]
# Out:
# config.json:   0%|          | 0.00/861 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/269M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.76k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/801k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]

# %% [markdown]
# ## Train model with DPO

# %%
# Training arguments
training_args = DPOConfig(
    # Training batch size per GPU
    per_device_train_batch_size=2,
    # Number of updates steps to accumulate before performing a backward/update pass
    # Effective batch size = per_device_train_batch_size * gradient_accumulation_steps
    gradient_accumulation_steps=4,
    # Saves memory by not storing activations during forward pass
    # Instead recomputes them during backward pass
    gradient_checkpointing=True,
    # Base learning rate for training
    learning_rate=5e-5,
    # Learning rate schedule - 'cosine' gradually decreases LR following cosine curve
    lr_scheduler_type="cosine",
    # Total number of training steps
    max_steps=200,
    # Disables model checkpointing during training
    save_strategy="no",
    # How often to log training metrics
    logging_steps=1,
    # Directory to save model outputs
    output_dir="smol_dpo_output",
    # Number of steps for learning rate warmup
    warmup_steps=100,
    # Use bfloat16 precision for faster training
    bf16=True,
    # Disable wandb/tensorboard logging
    report_to=None,
    # Keep all columns in dataset even if not used
    remove_unused_columns=False,
    # Enable MPS (Metal Performance Shaders) for Mac devices
    use_mps_device=device == "mps",
    # Model ID for HuggingFace Hub uploads
    hub_model_id=finetune_name,
)

# %%
trainer = DPOTrainer(
    # The model to be trained
    model=model,
    # Training configuration from above
    args=training_args,
    # Dataset containing preferred/rejected response pairs
    train_dataset=ds,
    # Tokenizer for processing inputs
    processing_class=tokenizer,
    # DPO-specific temperature parameter that controls the strength of the preference model
    # Lower values (like 0.1) make the model more conservative in following preferences
    #beta=0.1,
    # Maximum length of the input prompt in tokens
    #max_prompt_length=1024,
    # Maximum combined length of prompt + response in tokens
    #max_length=1536,
)
# Out:
# Applying chat template to train dataset:   0%|          | 0/62135 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/62135 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Train the model
trainer.train()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
# {'loss': 0.6931, 'grad_norm': 126.73368835449219, 'learning_rate': 5.000000000000001e-07, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -434.04522705078125, 'logps/rejected': -456.822998046875, 'logits/chosen': 4.4635748863220215, 'logits/rejected': 3.714787244796753, 'epoch': 0.0}
# {'loss': 0.6931, 'grad_norm': 102.54335021972656, 'learning_rate': 1.0000000000000002e-06, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -471.7196960449219, 'logps/rejected': -207.65591430664062, 'logits/chosen': 4.715658187866211, 'logits/rejected': 4.194499492645264, 'epoch': 0.0}
# {'loss': 0.712, 'grad_norm': 121.74797058105469, 'learning_rate': 1.5e-06, 'rewards/chosen': 0.00338586512953043, 'rewards/rejected': 0.03818888962268829, 'rewards/accuracies': 0.375, 'rewards/margins': -0.03480302169919014, 'logps/chosen': -420.8990478515625, 'logps/rejected': -399.0077209472656, 'logits/chosen': 4.434101581573486, 'logits/rejected': 4.522202491760254, 'epoch': 0.0}
# {'loss': 0.7185, 'grad_norm': 124.30278778076172, 'learning_rate': 2.0000000000000003e-06, 'rewards/chosen': -0.03210820257663727, 'rewards/rejected': 0.014991294592618942, 'rewards/accuracies': 0.375, 'rewards/margins': -0.04709949716925621, 'logps/chosen': -476.418212890625, 'logps/rejected': -375.91253662109375, 'logits/chosen': 4.0814971923828125, 'logits/rejected': 5.089338302612305, 'epoch': 0.0}
# {'loss': 0.6712, 'grad_norm': 114.50193786621094, 'learning_rate': 2.5e-06, 'rewards/chosen': 0.02633306011557579, 'rewards/rejected': -0.02093477174639702, 'rewards/accuracies': 0.625, 'rewards/margins': 0.04726783186197281, 'logps/chosen': -463.5481872558594, 'logps/rejected': -395.1261901855469, 'logits/chosen': 4.071087837219238, 'logits/rejected': 4.7225341796875, 'epoch': 0.0}
# {'loss': 0.6552, 'grad_norm': 136.1351318359375, 'learning_rate': 3e-06, 'rewards/chosen': 0.10541711747646332, 'rewards/rejected': 0.026550961658358574, 'rewards/accuracies': 0.75, 'rewards/margins': 0.0788661539554596, 'logps/chosen': -800.6854858398438, 'logps/rejected': -564.5194091796875, 'logits/chosen': 4.011871337890625, 'logits/rejected': 4.223432540893555, 'epoch': 0.0}
# {'loss': 0.7111, 'grad_norm': 88.32597351074219, 'learning_rate': 3.5000000000000004e-06, 'rewards/chosen': -0.011467836797237396, 'rewards/rejected': 0.021055150777101517, 'rewards/accuracies': 0.5, 'rewards/margins': -0.03252299129962921, 'logps/chosen': -261.42852783203125, 'logps/rejected': -233.8447265625, 'logits/chosen': 3.526413917541504, 'logits/rejected': 3.567669153213501, 'epoch': 0.0}
# {'loss': 0.6924, 'grad_norm': 95.66704559326172, 'learning_rate': 4.000000000000001e-06, 'rewards/chosen': -0.010066984221339226, 'rewards/rejected': -0.01428995095193386, 'rewards/accuracies': 0.25, 'rewards/margins': 0.004222968593239784, 'logps/chosen': -269.0819091796875, 'logps/rejected': -309.2894287109375, 'logits/chosen': 6.208700180053711, 'logits/rejected': 5.3912529945373535, 'epoch': 0.0}
# {'loss': 0.6844, 'grad_norm': 85.13426208496094, 'learning_rate': 4.5e-06, 'rewards/chosen': 0.013584349304437637, 'rewards/rejected': -0.008332419209182262, 'rewards/accuracies': 0.5, 'rewards/margins': 0.021916769444942474, 'logps/chosen': -310.4896240234375, 'logps/rejected': -168.53347778320312, 'logits/chosen': 3.4332995414733887, 'logits/rejected': 4.736200332641602, 'epoch': 0.0}
# {'loss': 0.6904, 'grad_norm': 103.18151092529297, 'learning_rate': 5e-06, 'rewards/chosen': -0.017848873510956764, 'rewards/rejected': -0.024672700092196465, 'rewards/accuracies': 0.5, 'rewards/margins': 0.006823826115578413, 'logps/chosen': -310.66064453125, 'logps/rejected': -338.4035949707031, 'logits/chosen': 3.2091426849365234, 'logits/rejected': 3.396491050720215, 'epoch': 0.0}
# {'loss': 0.7068, 'grad_norm': 84.81895446777344, 'learning_rate': 5.500000000000001e-06, 'rewards/chosen': 0.012821266427636147, 'rewards/rejected': 0.038097891956567764, 'rewards/accuracies': 0.375, 'rewards/margins': -0.025276625528931618, 'logps/chosen': -205.9683380126953, 'logps/rejected': -126.25199890136719, 'logits/chosen': 4.018402099609375, 'logits/rejected': 4.2271342277526855, 'epoch': 0.0}
# {'loss': 0.6838, 'grad_norm': 96.67877960205078, 'learning_rate': 6e-06, 'rewards/chosen': 0.0032260892912745476, 'rewards/rejected': -0.017364883795380592, 'rewards/accuracies': 0.5, 'rewards/margins': 0.020590974017977715, 'logps/chosen': -383.74749755859375, 'logps/rejected': -317.7916564941406, 'logits/chosen': 4.185410022735596, 'logits/rejected': 4.299461364746094, 'epoch': 0.0}
# {'loss': 0.7149, 'grad_norm': 143.9773406982422, 'learning_rate': 6.5000000000000004e-06, 'rewards/chosen': -0.00998153630644083, 'rewards/rejected': 0.031141020357608795, 'rewards/accuracies': 0.375, 'rewards/margins': -0.04112255573272705, 'logps/chosen': -743.0645141601562, 'logps/rejected': -393.46954345703125, 'logits/chosen': 3.9545459747314453, 'logits/rejected': 1.7852613925933838, 'epoch': 0.0}
# {'loss': 0.718, 'grad_norm': 128.9197540283203, 'learning_rate': 7.000000000000001e-06, 'rewards/chosen': -0.014745903201401234, 'rewards/rejected': 0.033229757100343704, 'rewards/accuracies': 0.25, 'rewards/margins': -0.04797565937042236, 'logps/chosen': -345.7381896972656, 'logps/rejected': -218.01519775390625, 'logits/chosen': 4.139551162719727, 'logits/rejected': 5.008362293243408, 'epoch': 0.0}
# {'loss': 0.7342, 'grad_norm': 132.820556640625, 'learning_rate': 7.5e-06, 'rewards/chosen': -0.06373361498117447, 'rewards/rejected': 0.011143685318529606, 'rewards/accuracies': 0.375, 'rewards/margins': -0.0748773068189621, 'logps/chosen': -463.1890563964844, 'logps/rejected': -385.83831787109375, 'logits/chosen': 5.213711738586426, 'logits/rejected': 5.365467548370361, 'epoch': 0.0}
# {'loss': 0.6797, 'grad_norm': 115.17495727539062, 'learning_rate': 8.000000000000001e-06, 'rewards/chosen': 0.007964909076690674, 'rewards/rejected': -0.020633220672607422, 'rewards/accuracies': 0.75, 'rewards/margins': 0.028598129749298096, 'logps/chosen': -495.4962158203125, 'logps/rejected': -303.72686767578125, 'logits/chosen': 1.896446943283081, 'logits/rejected': 3.654841661453247, 'epoch': 0.0}
# {'loss': 0.7016, 'grad_norm': 120.42822265625, 'learning_rate': 8.500000000000002e-06, 'rewards/chosen': -0.015000445768237114, 'rewards/rejected': 0.0007455060258507729, 'rewards/accuracies': 0.375, 'rewards/margins': -0.015745950862765312, 'logps/chosen': -385.4669189453125, 'logps/rejected': -246.29486083984375, 'logits/chosen': 5.370389938354492, 'logits/rejected': 4.512313365936279, 'epoch': 0.0}
# {'loss': 0.7336, 'grad_norm': 142.62954711914062, 'learning_rate': 9e-06, 'rewards/chosen': -0.028597068041563034, 'rewards/rejected': 0.04637913405895233, 'rewards/accuracies': 0.25, 'rewards/margins': -0.07497620582580566, 'logps/chosen': -558.0419921875, 'logps/rejected': -590.6507568359375, 'logits/chosen': 2.3135015964508057, 'logits/rejected': 2.5424509048461914, 'epoch': 0.0}
# {'loss': 0.6746, 'grad_norm': 103.07077026367188, 'learning_rate': 9.5e-06, 'rewards/chosen': 0.022939231246709824, 'rewards/rejected': -0.01672515831887722, 'rewards/accuracies': 0.625, 'rewards/margins': 0.039664387702941895, 'logps/chosen': -237.61825561523438, 'logps/rejected': -315.36541748046875, 'logits/chosen': 5.105434417724609, 'logits/rejected': 4.573788642883301, 'epoch': 0.0}
# {'loss': 0.7071, 'grad_norm': 104.72444152832031, 'learning_rate': 1e-05, 'rewards/chosen': -0.017958832904696465, 'rewards/rejected': 0.00835199374705553, 'rewards/accuracies': 0.5, 'rewards/margins': -0.02631082385778427, 'logps/chosen': -314.5721435546875, 'logps/rejected': -365.8135070800781, 'logits/chosen': 3.2532331943511963, 'logits/rejected': 3.7061240673065186, 'epoch': 0.0}
# {'loss': 0.7083, 'grad_norm': 128.27745056152344, 'learning_rate': 1.05e-05, 'rewards/chosen': -0.01907205581665039, 'rewards/rejected': 0.01056809350848198, 'rewards/accuracies': 0.25, 'rewards/margins': -0.02964014932513237, 'logps/chosen': -472.7747497558594, 'logps/rejected': -413.9798583984375, 'logits/chosen': 4.591923236846924, 'logits/rejected': 4.576294422149658, 'epoch': 0.0}
# {'loss': 0.7084, 'grad_norm': 103.95803833007812, 'learning_rate': 1.1000000000000001e-05, 'rewards/chosen': -0.03807835653424263, 'rewards/rejected': -0.00896911695599556, 'rewards/accuracies': 0.25, 'rewards/margins': -0.02910923957824707, 'logps/chosen': -343.4649658203125, 'logps/rejected': -268.118896484375, 'logits/chosen': 3.5667531490325928, 'logits/rejected': 3.5224123001098633, 'epoch': 0.0}
# {'loss': 0.6395, 'grad_norm': 139.3900604248047, 'learning_rate': 1.1500000000000002e-05, 'rewards/chosen': 0.03168606758117676, 'rewards/rejected': -0.08348923176527023, 'rewards/accuracies': 0.75, 'rewards/margins': 0.1151752918958664, 'logps/chosen': -548.7098999023438, 'logps/rejected': -666.5687255859375, 'logits/chosen': 2.585222005844116, 'logits/rejected': 3.864295482635498, 'epoch': 0.0}
# {'loss': 0.7195, 'grad_norm': 113.21178436279297, 'learning_rate': 1.2e-05, 'rewards/chosen': -0.054000284522771835, 'rewards/rejected': -0.005756343249231577, 'rewards/accuracies': 0.25, 'rewards/margins': -0.048243939876556396, 'logps/chosen': -353.1485290527344, 'logps/rejected': -347.4014892578125, 'logits/chosen': 3.404928207397461, 'logits/rejected': 4.138649940490723, 'epoch': 0.0}
# {'loss': 0.7014, 'grad_norm': 118.75106811523438, 'learning_rate': 1.25e-05, 'rewards/chosen': -0.024992847815155983, 'rewards/rejected': -0.012266349047422409, 'rewards/accuracies': 0.75, 'rewards/margins': -0.012726496905088425, 'logps/chosen': -341.9835205078125, 'logps/rejected': -326.59130859375, 'logits/chosen': 5.708927154541016, 'logits/rejected': 5.36638879776001, 'epoch': 0.0}
# {'loss': 0.6439, 'grad_norm': 126.08160400390625, 'learning_rate': 1.3000000000000001e-05, 'rewards/chosen': 0.03573460504412651, 'rewards/rejected': -0.07101258635520935, 'rewards/accuracies': 0.875, 'rewards/margins': 0.10674719512462616, 'logps/chosen': -636.4497680664062, 'logps/rejected': -572.31591796875, 'logits/chosen': 4.967572212219238, 'logits/rejected': 3.466844320297241, 'epoch': 0.0}
# {'loss': 0.692, 'grad_norm': 98.41507720947266, 'learning_rate': 1.3500000000000001e-05, 'rewards/chosen': 0.013850437477231026, 'rewards/rejected': 0.009430551901459694, 'rewards/accuracies': 0.625, 'rewards/margins': 0.004419885575771332, 'logps/chosen': -282.2803039550781, 'logps/rejected': -175.2124786376953, 'logits/chosen': 3.2652556896209717, 'logits/rejected': 4.401188850402832, 'epoch': 0.0}
# {'loss': 0.6545, 'grad_norm': 113.38711547851562, 'learning_rate': 1.4000000000000001e-05, 'rewards/chosen': 0.05958025902509689, 'rewards/rejected': -0.020709801465272903, 'rewards/accuracies': 0.875, 'rewards/margins': 0.0802900567650795, 'logps/chosen': -432.8714904785156, 'logps/rejected': -394.32843017578125, 'logits/chosen': 2.819370746612549, 'logits/rejected': 4.6855082511901855, 'epoch': 0.0}
# {'loss': 0.7016, 'grad_norm': 122.58149719238281, 'learning_rate': 1.45e-05, 'rewards/chosen': -0.04126422852277756, 'rewards/rejected': -0.02531302347779274, 'rewards/accuracies': 0.375, 'rewards/margins': -0.015951205044984818, 'logps/chosen': -529.634765625, 'logps/rejected': -441.25128173828125, 'logits/chosen': 1.7489298582077026, 'logits/rejected': 2.949138879776001, 'epoch': 0.0}
# {'loss': 0.6691, 'grad_norm': 86.54296112060547, 'learning_rate': 1.5e-05, 'rewards/chosen': 0.00014852732419967651, 'rewards/rejected': -0.05117487907409668, 'rewards/accuracies': 0.75, 'rewards/margins': 0.051323406398296356, 'logps/chosen': -288.82037353515625, 'logps/rejected': -201.09341430664062, 'logits/chosen': 3.782897472381592, 'logits/rejected': 2.654940605163574, 'epoch': 0.0}
# {'loss': 0.6955, 'grad_norm': 93.35833740234375, 'learning_rate': 1.55e-05, 'rewards/chosen': -0.0267912857234478, 'rewards/rejected': -0.023449938744306564, 'rewards/accuracies': 0.5, 'rewards/margins': -0.003341350704431534, 'logps/chosen': -275.0477294921875, 'logps/rejected': -208.509765625, 'logits/chosen': 3.857367992401123, 'logits/rejected': 3.782576084136963, 'epoch': 0.0}
# {'loss': 0.675, 'grad_norm': 147.9824676513672, 'learning_rate': 1.6000000000000003e-05, 'rewards/chosen': -0.02892027050256729, 'rewards/rejected': -0.06985434889793396, 'rewards/accuracies': 0.625, 'rewards/margins': 0.04093408212065697, 'logps/chosen': -635.393798828125, 'logps/rejected': -474.20819091796875, 'logits/chosen': 4.942893981933594, 'logits/rejected': 3.9132602214813232, 'epoch': 0.0}
# {'loss': 0.6635, 'grad_norm': 81.1492691040039, 'learning_rate': 1.65e-05, 'rewards/chosen': 0.01828211545944214, 'rewards/rejected': -0.046357087790966034, 'rewards/accuracies': 0.5, 'rewards/margins': 0.06463920325040817, 'logps/chosen': -306.4837341308594, 'logps/rejected': -217.8463897705078, 'logits/chosen': 2.2896766662597656, 'logits/rejected': 2.644533395767212, 'epoch': 0.0}
# {'loss': 0.7092, 'grad_norm': 137.66017150878906, 'learning_rate': 1.7000000000000003e-05, 'rewards/chosen': -0.06338964402675629, 'rewards/rejected': -0.0364958792924881, 'rewards/accuracies': 0.625, 'rewards/margins': -0.02689375914633274, 'logps/chosen': -575.6966552734375, 'logps/rejected': -564.880615234375, 'logits/chosen': 1.8656883239746094, 'logits/rejected': 3.1887354850769043, 'epoch': 0.0}
# {'loss': 0.6659, 'grad_norm': 78.08000183105469, 'learning_rate': 1.75e-05, 'rewards/chosen': -0.05256852135062218, 'rewards/rejected': -0.1092383936047554, 'rewards/accuracies': 0.625, 'rewards/margins': 0.056669868528842926, 'logps/chosen': -207.52284240722656, 'logps/rejected': -248.81838989257812, 'logits/chosen': 2.815601348876953, 'logits/rejected': 2.8450560569763184, 'epoch': 0.0}
# {'loss': 0.6399, 'grad_norm': 128.6089324951172, 'learning_rate': 1.8e-05, 'rewards/chosen': 0.023203277960419655, 'rewards/rejected': -0.09324292838573456, 'rewards/accuracies': 0.75, 'rewards/margins': 0.11644621193408966, 'logps/chosen': -716.1358642578125, 'logps/rejected': -410.9217529296875, 'logits/chosen': 3.309866428375244, 'logits/rejected': 3.9728567600250244, 'epoch': 0.0}
# {'loss': 0.6963, 'grad_norm': 109.49583435058594, 'learning_rate': 1.85e-05, 'rewards/chosen': -0.07210603356361389, 'rewards/rejected': -0.06999845802783966, 'rewards/accuracies': 0.5, 'rewards/margins': -0.002107568085193634, 'logps/chosen': -398.5133056640625, 'logps/rejected': -281.36334228515625, 'logits/chosen': 2.977780818939209, 'logits/rejected': 3.404568672180176, 'epoch': 0.0}
# {'loss': 0.6577, 'grad_norm': 114.79119873046875, 'learning_rate': 1.9e-05, 'rewards/chosen': -0.02358679659664631, 'rewards/rejected': -0.09955248981714249, 'rewards/accuracies': 0.625, 'rewards/margins': 0.07596568763256073, 'logps/chosen': -428.68365478515625, 'logps/rejected': -404.0022277832031, 'logits/chosen': 4.267448902130127, 'logits/rejected': 3.6094300746917725, 'epoch': 0.0}
# {'loss': 0.6678, 'grad_norm': 106.53900146484375, 'learning_rate': 1.9500000000000003e-05, 'rewards/chosen': -0.03335290029644966, 'rewards/rejected': -0.08671245723962784, 'rewards/accuracies': 0.625, 'rewards/margins': 0.05335955694317818, 'logps/chosen': -442.88873291015625, 'logps/rejected': -291.7952880859375, 'logits/chosen': 3.4502696990966797, 'logits/rejected': 3.9724550247192383, 'epoch': 0.01}
# {'loss': 0.644, 'grad_norm': 87.1893310546875, 'learning_rate': 2e-05, 'rewards/chosen': -0.03946806490421295, 'rewards/rejected': -0.14322297275066376, 'rewards/accuracies': 0.875, 'rewards/margins': 0.1037549152970314, 'logps/chosen': -266.2088623046875, 'logps/rejected': -292.2540283203125, 'logits/chosen': 4.11663818359375, 'logits/rejected': 4.010062217712402, 'epoch': 0.01}
# {'loss': 0.6168, 'grad_norm': 110.32695770263672, 'learning_rate': 2.05e-05, 'rewards/chosen': 0.00876769982278347, 'rewards/rejected': -0.16215287148952484, 'rewards/accuracies': 0.875, 'rewards/margins': 0.17092058062553406, 'logps/chosen': -673.92822265625, 'logps/rejected': -280.3866271972656, 'logits/chosen': 5.130090236663818, 'logits/rejected': 4.826114177703857, 'epoch': 0.01}
# {'loss': 0.6364, 'grad_norm': 90.07487487792969, 'learning_rate': 2.1e-05, 'rewards/chosen': -0.0277448408305645, 'rewards/rejected': -0.15553218126296997, 'rewards/accuracies': 0.75, 'rewards/margins': 0.12778733670711517, 'logps/chosen': -199.15362548828125, 'logps/rejected': -469.67449951171875, 'logits/chosen': 3.5677902698516846, 'logits/rejected': 3.913248062133789, 'epoch': 0.01}
# {'loss': 0.5967, 'grad_norm': 115.3791275024414, 'learning_rate': 2.15e-05, 'rewards/chosen': 0.02775735780596733, 'rewards/rejected': -0.2013178914785385, 'rewards/accuracies': 0.75, 'rewards/margins': 0.22907523810863495, 'logps/chosen': -680.1533813476562, 'logps/rejected': -500.33660888671875, 'logits/chosen': 4.458456993103027, 'logits/rejected': 3.7490947246551514, 'epoch': 0.01}
# {'loss': 0.6735, 'grad_norm': 91.16510772705078, 'learning_rate': 2.2000000000000003e-05, 'rewards/chosen': -0.06886091828346252, 'rewards/rejected': -0.11969853937625885, 'rewards/accuracies': 0.5, 'rewards/margins': 0.05083761364221573, 'logps/chosen': -286.7143859863281, 'logps/rejected': -304.47454833984375, 'logits/chosen': 4.2726640701293945, 'logits/rejected': 3.524247407913208, 'epoch': 0.01}
# {'loss': 0.6919, 'grad_norm': 110.020263671875, 'learning_rate': 2.25e-05, 'rewards/chosen': -0.09144461899995804, 'rewards/rejected': -0.09845707565546036, 'rewards/accuracies': 0.625, 'rewards/margins': 0.007012458518147469, 'logps/chosen': -261.0067138671875, 'logps/rejected': -379.976806640625, 'logits/chosen': 5.007879734039307, 'logits/rejected': 5.566098690032959, 'epoch': 0.01}
# {'loss': 0.6729, 'grad_norm': 89.48445129394531, 'learning_rate': 2.3000000000000003e-05, 'rewards/chosen': -0.09009666740894318, 'rewards/rejected': -0.14227032661437988, 'rewards/accuracies': 0.625, 'rewards/margins': 0.05217365175485611, 'logps/chosen': -239.88101196289062, 'logps/rejected': -178.5218048095703, 'logits/chosen': 2.4681320190429688, 'logits/rejected': 3.1278233528137207, 'epoch': 0.01}
# {'loss': 0.6727, 'grad_norm': 118.63594055175781, 'learning_rate': 2.35e-05, 'rewards/chosen': -0.06610363721847534, 'rewards/rejected': -0.12028531730175018, 'rewards/accuracies': 0.75, 'rewards/margins': 0.05418168753385544, 'logps/chosen': -506.56744384765625, 'logps/rejected': -523.64599609375, 'logits/chosen': 3.545795440673828, 'logits/rejected': 3.8317930698394775, 'epoch': 0.01}
# {'loss': 0.6909, 'grad_norm': 93.39353942871094, 'learning_rate': 2.4e-05, 'rewards/chosen': -0.07530877739191055, 'rewards/rejected': -0.12805971503257751, 'rewards/accuracies': 0.5, 'rewards/margins': 0.05275092273950577, 'logps/chosen': -414.0030212402344, 'logps/rejected': -313.38232421875, 'logits/chosen': 4.268679618835449, 'logits/rejected': 4.060175895690918, 'epoch': 0.01}
# {'loss': 0.6528, 'grad_norm': 74.09749603271484, 'learning_rate': 2.45e-05, 'rewards/chosen': -0.02361450344324112, 'rewards/rejected': -0.12456086277961731, 'rewards/accuracies': 0.5, 'rewards/margins': 0.10094636678695679, 'logps/chosen': -366.9097900390625, 'logps/rejected': -113.28231811523438, 'logits/chosen': 4.115397930145264, 'logits/rejected': 3.3415043354034424, 'epoch': 0.01}
# {'loss': 0.6896, 'grad_norm': 99.80467224121094, 'learning_rate': 2.5e-05, 'rewards/chosen': -0.21970872581005096, 'rewards/rejected': -0.23782654106616974, 'rewards/accuracies': 0.5, 'rewards/margins': 0.018117815256118774, 'logps/chosen': -489.57281494140625, 'logps/rejected': -363.52081298828125, 'logits/chosen': 2.2689177989959717, 'logits/rejected': 3.15529203414917, 'epoch': 0.01}
# {'loss': 0.6515, 'grad_norm': 84.35420227050781, 'learning_rate': 2.5500000000000003e-05, 'rewards/chosen': -0.0915304571390152, 'rewards/rejected': -0.19741880893707275, 'rewards/accuracies': 0.5, 'rewards/margins': 0.10588833689689636, 'logps/chosen': -305.1454772949219, 'logps/rejected': -248.96392822265625, 'logits/chosen': 3.3681557178497314, 'logits/rejected': 3.766108512878418, 'epoch': 0.01}
# {'loss': 0.6341, 'grad_norm': 102.16394805908203, 'learning_rate': 2.6000000000000002e-05, 'rewards/chosen': -0.06428057700395584, 'rewards/rejected': -0.20772862434387207, 'rewards/accuracies': 0.75, 'rewards/margins': 0.14344803988933563, 'logps/chosen': -353.74871826171875, 'logps/rejected': -200.49786376953125, 'logits/chosen': 4.883701801300049, 'logits/rejected': 4.826836585998535, 'epoch': 0.01}
# {'loss': 0.6707, 'grad_norm': 99.20840454101562, 'learning_rate': 2.6500000000000004e-05, 'rewards/chosen': -0.17719250917434692, 'rewards/rejected': -0.2305625081062317, 'rewards/accuracies': 0.75, 'rewards/margins': 0.053369998931884766, 'logps/chosen': -378.4874267578125, 'logps/rejected': -272.16796875, 'logits/chosen': 4.152241230010986, 'logits/rejected': 4.633681774139404, 'epoch': 0.01}
# {'loss': 0.5805, 'grad_norm': 90.26615142822266, 'learning_rate': 2.7000000000000002e-05, 'rewards/chosen': -0.033454012125730515, 'rewards/rejected': -0.2933408319950104, 'rewards/accuracies': 0.75, 'rewards/margins': 0.25988683104515076, 'logps/chosen': -312.0745849609375, 'logps/rejected': -339.6985778808594, 'logits/chosen': 4.802680015563965, 'logits/rejected': 4.2270307540893555, 'epoch': 0.01}
# {'loss': 0.6172, 'grad_norm': 96.47186279296875, 'learning_rate': 2.7500000000000004e-05, 'rewards/chosen': -0.08273929357528687, 'rewards/rejected': -0.272560715675354, 'rewards/accuracies': 0.75, 'rewards/margins': 0.18982140719890594, 'logps/chosen': -258.226318359375, 'logps/rejected': -393.8443298339844, 'logits/chosen': 3.542266845703125, 'logits/rejected': 4.5798163414001465, 'epoch': 0.01}
# {'loss': 0.6432, 'grad_norm': 120.96977233886719, 'learning_rate': 2.8000000000000003e-05, 'rewards/chosen': -0.09309761971235275, 'rewards/rejected': -0.3057127296924591, 'rewards/accuracies': 0.625, 'rewards/margins': 0.21261510252952576, 'logps/chosen': -369.658203125, 'logps/rejected': -463.7688293457031, 'logits/chosen': 3.281104564666748, 'logits/rejected': 3.6076998710632324, 'epoch': 0.01}
# {'loss': 0.6311, 'grad_norm': 146.33168029785156, 'learning_rate': 2.8499999999999998e-05, 'rewards/chosen': -0.2025919407606125, 'rewards/rejected': -0.35018274188041687, 'rewards/accuracies': 0.75, 'rewards/margins': 0.147590771317482, 'logps/chosen': -690.467529296875, 'logps/rejected': -483.58697509765625, 'logits/chosen': 2.6469554901123047, 'logits/rejected': 3.1459431648254395, 'epoch': 0.01}
# {'loss': 0.6121, 'grad_norm': 106.0595474243164, 'learning_rate': 2.9e-05, 'rewards/chosen': -0.27851974964141846, 'rewards/rejected': -0.47892045974731445, 'rewards/accuracies': 0.75, 'rewards/margins': 0.2004007250070572, 'logps/chosen': -475.271728515625, 'logps/rejected': -484.6857604980469, 'logits/chosen': 4.15790319442749, 'logits/rejected': 3.5132508277893066, 'epoch': 0.01}
# {'loss': 0.6607, 'grad_norm': 71.67109680175781, 'learning_rate': 2.95e-05, 'rewards/chosen': -0.23807622492313385, 'rewards/rejected': -0.3187006413936615, 'rewards/accuracies': 0.75, 'rewards/margins': 0.08062440156936646, 'logps/chosen': -146.03404235839844, 'logps/rejected': -228.37977600097656, 'logits/chosen': 4.088342666625977, 'logits/rejected': 2.919642925262451, 'epoch': 0.01}
# {'loss': 0.5815, 'grad_norm': 99.96379089355469, 'learning_rate': 3e-05, 'rewards/chosen': -0.002896786667406559, 'rewards/rejected': -0.27602076530456543, 'rewards/accuracies': 0.75, 'rewards/margins': 0.27312397956848145, 'logps/chosen': -501.8441467285156, 'logps/rejected': -262.6844482421875, 'logits/chosen': 2.765117645263672, 'logits/rejected': 1.8191993236541748, 'epoch': 0.01}
# {'loss': 0.7339, 'grad_norm': 138.6389923095703, 'learning_rate': 3.05e-05, 'rewards/chosen': -0.3264513909816742, 'rewards/rejected': -0.32177287340164185, 'rewards/accuracies': 0.5, 'rewards/margins': -0.004678547382354736, 'logps/chosen': -583.7666625976562, 'logps/rejected': -363.6363525390625, 'logits/chosen': 5.277418613433838, 'logits/rejected': 3.5235331058502197, 'epoch': 0.01}
# {'loss': 0.6445, 'grad_norm': 117.53114318847656, 'learning_rate': 3.1e-05, 'rewards/chosen': -0.35886937379837036, 'rewards/rejected': -0.49829739332199097, 'rewards/accuracies': 0.625, 'rewards/margins': 0.139428049325943, 'logps/chosen': -448.0502624511719, 'logps/rejected': -498.1579284667969, 'logits/chosen': 3.875339984893799, 'logits/rejected': 3.600278377532959, 'epoch': 0.01}
# {'loss': 0.6313, 'grad_norm': 66.64041900634766, 'learning_rate': 3.15e-05, 'rewards/chosen': -0.17576558887958527, 'rewards/rejected': -0.32719892263412476, 'rewards/accuracies': 0.75, 'rewards/margins': 0.1514333188533783, 'logps/chosen': -141.66281127929688, 'logps/rejected': -161.79379272460938, 'logits/chosen': 4.022730350494385, 'logits/rejected': 3.89933443069458, 'epoch': 0.01}
# {'loss': 0.5639, 'grad_norm': 82.41349029541016, 'learning_rate': 3.2000000000000005e-05, 'rewards/chosen': -0.007832441478967667, 'rewards/rejected': -0.3337525725364685, 'rewards/accuracies': 0.75, 'rewards/margins': 0.32592013478279114, 'logps/chosen': -357.345703125, 'logps/rejected': -217.9775390625, 'logits/chosen': 4.165499687194824, 'logits/rejected': 4.466981410980225, 'epoch': 0.01}
# {'loss': 0.6383, 'grad_norm': 75.83570098876953, 'learning_rate': 3.2500000000000004e-05, 'rewards/chosen': -0.2128676474094391, 'rewards/rejected': -0.41146525740623474, 'rewards/accuracies': 0.625, 'rewards/margins': 0.19859760999679565, 'logps/chosen': -285.47796630859375, 'logps/rejected': -270.24420166015625, 'logits/chosen': 2.360947847366333, 'logits/rejected': 3.3705220222473145, 'epoch': 0.01}
# {'loss': 0.7226, 'grad_norm': 100.67244720458984, 'learning_rate': 3.3e-05, 'rewards/chosen': -0.3914301097393036, 'rewards/rejected': -0.4083430767059326, 'rewards/accuracies': 0.625, 'rewards/margins': 0.016912974417209625, 'logps/chosen': -307.0697937011719, 'logps/rejected': -264.63970947265625, 'logits/chosen': 3.5823426246643066, 'logits/rejected': 4.23174524307251, 'epoch': 0.01}
# {'loss': 0.5322, 'grad_norm': 98.05829620361328, 'learning_rate': 3.35e-05, 'rewards/chosen': -0.3039705455303192, 'rewards/rejected': -0.6747957468032837, 'rewards/accuracies': 1.0, 'rewards/margins': 0.37082523107528687, 'logps/chosen': -555.732421875, 'logps/rejected': -459.5503845214844, 'logits/chosen': 3.5940260887145996, 'logits/rejected': 3.281691551208496, 'epoch': 0.01}
# {'loss': 0.8306, 'grad_norm': 115.58879089355469, 'learning_rate': 3.4000000000000007e-05, 'rewards/chosen': -0.7068304419517517, 'rewards/rejected': -0.4857661724090576, 'rewards/accuracies': 0.125, 'rewards/margins': -0.22106431424617767, 'logps/chosen': -400.08172607421875, 'logps/rejected': -346.912353515625, 'logits/chosen': 2.7445857524871826, 'logits/rejected': 1.9655205011367798, 'epoch': 0.01}
# {'loss': 0.5454, 'grad_norm': 93.5167007446289, 'learning_rate': 3.45e-05, 'rewards/chosen': -0.26678603887557983, 'rewards/rejected': -0.619982123374939, 'rewards/accuracies': 0.875, 'rewards/margins': 0.3531961441040039, 'logps/chosen': -324.5653991699219, 'logps/rejected': -414.0731201171875, 'logits/chosen': 2.7886810302734375, 'logits/rejected': 2.2473740577697754, 'epoch': 0.01}
# {'loss': 0.7342, 'grad_norm': 89.2513656616211, 'learning_rate': 3.5e-05, 'rewards/chosen': -0.4671095013618469, 'rewards/rejected': -0.4805655777454376, 'rewards/accuracies': 0.625, 'rewards/margins': 0.013456039130687714, 'logps/chosen': -283.53436279296875, 'logps/rejected': -179.36058044433594, 'logits/chosen': 2.0972726345062256, 'logits/rejected': 2.846524953842163, 'epoch': 0.01}
# {'loss': 0.5516, 'grad_norm': 86.7413558959961, 'learning_rate': 3.55e-05, 'rewards/chosen': -0.31511154770851135, 'rewards/rejected': -0.8069577217102051, 'rewards/accuracies': 0.625, 'rewards/margins': 0.4918462038040161, 'logps/chosen': -527.78564453125, 'logps/rejected': -299.49041748046875, 'logits/chosen': 2.760361671447754, 'logits/rejected': 3.478152275085449, 'epoch': 0.01}
# {'loss': 0.6435, 'grad_norm': 117.0927734375, 'learning_rate': 3.6e-05, 'rewards/chosen': -0.693817138671875, 'rewards/rejected': -0.8861638903617859, 'rewards/accuracies': 0.375, 'rewards/margins': 0.19234676659107208, 'logps/chosen': -470.4474792480469, 'logps/rejected': -323.55462646484375, 'logits/chosen': 3.106539726257324, 'logits/rejected': 4.588676929473877, 'epoch': 0.01}
# {'loss': 0.8706, 'grad_norm': 138.6857147216797, 'learning_rate': 3.65e-05, 'rewards/chosen': -0.7292396426200867, 'rewards/rejected': -0.5088432431221008, 'rewards/accuracies': 0.375, 'rewards/margins': -0.22039632499217987, 'logps/chosen': -389.080322265625, 'logps/rejected': -484.3310852050781, 'logits/chosen': 4.0392866134643555, 'logits/rejected': 3.607304096221924, 'epoch': 0.01}
# {'loss': 0.6279, 'grad_norm': 113.05963134765625, 'learning_rate': 3.7e-05, 'rewards/chosen': -0.4461686313152313, 'rewards/rejected': -0.6562417149543762, 'rewards/accuracies': 0.75, 'rewards/margins': 0.2100730836391449, 'logps/chosen': -512.5824584960938, 'logps/rejected': -396.3870544433594, 'logits/chosen': 2.687830924987793, 'logits/rejected': 2.058192491531372, 'epoch': 0.01}
# {'loss': 0.767, 'grad_norm': 142.74461364746094, 'learning_rate': 3.7500000000000003e-05, 'rewards/chosen': -0.7202430367469788, 'rewards/rejected': -0.6367778182029724, 'rewards/accuracies': 0.375, 'rewards/margins': -0.0834653228521347, 'logps/chosen': -401.55218505859375, 'logps/rejected': -453.9049377441406, 'logits/chosen': 3.1338090896606445, 'logits/rejected': 3.5250823497772217, 'epoch': 0.01}
# {'loss': 0.453, 'grad_norm': 66.1095199584961, 'learning_rate': 3.8e-05, 'rewards/chosen': -0.20258551836013794, 'rewards/rejected': -0.9660589098930359, 'rewards/accuracies': 0.75, 'rewards/margins': 0.763473391532898, 'logps/chosen': -258.263427734375, 'logps/rejected': -304.35791015625, 'logits/chosen': 5.584694862365723, 'logits/rejected': 4.401536464691162, 'epoch': 0.01}
# {'loss': 0.669, 'grad_norm': 145.70196533203125, 'learning_rate': 3.85e-05, 'rewards/chosen': -0.3086417615413666, 'rewards/rejected': -0.42518872022628784, 'rewards/accuracies': 0.5, 'rewards/margins': 0.11654700338840485, 'logps/chosen': -637.8424682617188, 'logps/rejected': -522.66748046875, 'logits/chosen': 4.703770637512207, 'logits/rejected': 3.686478614807129, 'epoch': 0.01}
# {'loss': 0.6423, 'grad_norm': 142.04818725585938, 'learning_rate': 3.9000000000000006e-05, 'rewards/chosen': -0.5598489046096802, 'rewards/rejected': -0.764295220375061, 'rewards/accuracies': 0.75, 'rewards/margins': 0.20444628596305847, 'logps/chosen': -630.6934204101562, 'logps/rejected': -394.58782958984375, 'logits/chosen': 2.890427827835083, 'logits/rejected': 2.723212957382202, 'epoch': 0.01}
# {'loss': 0.8041, 'grad_norm': 108.29154205322266, 'learning_rate': 3.9500000000000005e-05, 'rewards/chosen': -0.48558473587036133, 'rewards/rejected': -0.43540266156196594, 'rewards/accuracies': 0.375, 'rewards/margins': -0.050182029604911804, 'logps/chosen': -328.56494140625, 'logps/rejected': -291.25732421875, 'logits/chosen': 4.057516574859619, 'logits/rejected': 4.786144256591797, 'epoch': 0.01}
# {'loss': 0.6181, 'grad_norm': 104.72565460205078, 'learning_rate': 4e-05, 'rewards/chosen': -0.7547285556793213, 'rewards/rejected': -0.997791051864624, 'rewards/accuracies': 0.75, 'rewards/margins': 0.24306254088878632, 'logps/chosen': -339.40087890625, 'logps/rejected': -458.0040283203125, 'logits/chosen': 3.105346202850342, 'logits/rejected': 3.6413614749908447, 'epoch': 0.01}
# {'loss': 0.6327, 'grad_norm': 105.99566650390625, 'learning_rate': 4.05e-05, 'rewards/chosen': -0.8775843381881714, 'rewards/rejected': -1.1149746179580688, 'rewards/accuracies': 0.5, 'rewards/margins': 0.23739023506641388, 'logps/chosen': -669.3560791015625, 'logps/rejected': -373.41326904296875, 'logits/chosen': 3.226229667663574, 'logits/rejected': 3.275630235671997, 'epoch': 0.01}
# {'loss': 0.6578, 'grad_norm': 120.65180969238281, 'learning_rate': 4.1e-05, 'rewards/chosen': -0.2970218062400818, 'rewards/rejected': -0.47177228331565857, 'rewards/accuracies': 0.625, 'rewards/margins': 0.17475049197673798, 'logps/chosen': -350.76690673828125, 'logps/rejected': -380.8789367675781, 'logits/chosen': 2.32924485206604, 'logits/rejected': 3.169736385345459, 'epoch': 0.01}
# {'loss': 1.0448, 'grad_norm': 159.78529357910156, 'learning_rate': 4.15e-05, 'rewards/chosen': -1.0290383100509644, 'rewards/rejected': -0.5667675137519836, 'rewards/accuracies': 0.375, 'rewards/margins': -0.4622708261013031, 'logps/chosen': -407.11688232421875, 'logps/rejected': -490.2271728515625, 'logits/chosen': 3.3987653255462646, 'logits/rejected': 4.073421478271484, 'epoch': 0.01}
# {'loss': 0.6862, 'grad_norm': 110.99750518798828, 'learning_rate': 4.2e-05, 'rewards/chosen': -0.651028037071228, 'rewards/rejected': -0.8491986989974976, 'rewards/accuracies': 0.75, 'rewards/margins': 0.1981707513332367, 'logps/chosen': -384.2041015625, 'logps/rejected': -338.38330078125, 'logits/chosen': 4.902199745178223, 'logits/rejected': 3.0156993865966797, 'epoch': 0.01}
# {'loss': 0.7335, 'grad_norm': 128.42486572265625, 'learning_rate': 4.25e-05, 'rewards/chosen': -0.9153111577033997, 'rewards/rejected': -1.0504748821258545, 'rewards/accuracies': 0.5, 'rewards/margins': 0.13516369462013245, 'logps/chosen': -529.5662841796875, 'logps/rejected': -408.4185485839844, 'logits/chosen': 3.102743148803711, 'logits/rejected': 3.7633767127990723, 'epoch': 0.01}
# {'loss': 0.4688, 'grad_norm': 115.35528564453125, 'learning_rate': 4.3e-05, 'rewards/chosen': -0.6476909518241882, 'rewards/rejected': -1.508863925933838, 'rewards/accuracies': 0.625, 'rewards/margins': 0.8611730337142944, 'logps/chosen': -539.312255859375, 'logps/rejected': -523.7202758789062, 'logits/chosen': 2.075057029724121, 'logits/rejected': 3.6501591205596924, 'epoch': 0.01}
# {'loss': 0.619, 'grad_norm': 67.4852294921875, 'learning_rate': 4.35e-05, 'rewards/chosen': -0.47791787981987, 'rewards/rejected': -0.6976280212402344, 'rewards/accuracies': 0.625, 'rewards/margins': 0.21971012651920319, 'logps/chosen': -111.79637145996094, 'logps/rejected': -187.8848419189453, 'logits/chosen': 4.301277160644531, 'logits/rejected': 3.504026412963867, 'epoch': 0.01}
# {'loss': 1.0042, 'grad_norm': 145.3141326904297, 'learning_rate': 4.4000000000000006e-05, 'rewards/chosen': -1.0380078554153442, 'rewards/rejected': -0.5838813781738281, 'rewards/accuracies': 0.25, 'rewards/margins': -0.4541264772415161, 'logps/chosen': -406.55462646484375, 'logps/rejected': -308.2008361816406, 'logits/chosen': 3.862663507461548, 'logits/rejected': 2.819611072540283, 'epoch': 0.01}
# {'loss': 0.6838, 'grad_norm': 126.48909759521484, 'learning_rate': 4.4500000000000004e-05, 'rewards/chosen': -0.7686723470687866, 'rewards/rejected': -0.9235601425170898, 'rewards/accuracies': 0.5, 'rewards/margins': 0.1548878699541092, 'logps/chosen': -728.8287353515625, 'logps/rejected': -405.6629638671875, 'logits/chosen': 2.9679481983184814, 'logits/rejected': 1.2332743406295776, 'epoch': 0.01}
# {'loss': 0.6058, 'grad_norm': 114.63695526123047, 'learning_rate': 4.5e-05, 'rewards/chosen': -0.6859432458877563, 'rewards/rejected': -0.9512189626693726, 'rewards/accuracies': 0.625, 'rewards/margins': 0.26527565717697144, 'logps/chosen': -560.3700561523438, 'logps/rejected': -462.7380065917969, 'logits/chosen': 2.8241147994995117, 'logits/rejected': 4.344679832458496, 'epoch': 0.01}
# {'loss': 0.832, 'grad_norm': 132.15280151367188, 'learning_rate': 4.55e-05, 'rewards/chosen': -0.6201379299163818, 'rewards/rejected': -0.7335948944091797, 'rewards/accuracies': 0.5, 'rewards/margins': 0.11345691978931427, 'logps/chosen': -556.7999267578125, 'logps/rejected': -373.8630065917969, 'logits/chosen': 1.4322766065597534, 'logits/rejected': 1.1034677028656006, 'epoch': 0.01}
# {'loss': 0.4688, 'grad_norm': 84.85633850097656, 'learning_rate': 4.600000000000001e-05, 'rewards/chosen': -0.35924363136291504, 'rewards/rejected': -1.125251054763794, 'rewards/accuracies': 0.875, 'rewards/margins': 0.7660074234008789, 'logps/chosen': -433.4986572265625, 'logps/rejected': -310.61114501953125, 'logits/chosen': 3.4065089225769043, 'logits/rejected': 2.4242897033691406, 'epoch': 0.01}
# {'loss': 0.5609, 'grad_norm': 119.00958251953125, 'learning_rate': 4.6500000000000005e-05, 'rewards/chosen': -0.4511628746986389, 'rewards/rejected': -1.1089389324188232, 'rewards/accuracies': 0.625, 'rewards/margins': 0.6577761173248291, 'logps/chosen': -456.6322937011719, 'logps/rejected': -417.4024353027344, 'logits/chosen': 2.6908998489379883, 'logits/rejected': 3.5803682804107666, 'epoch': 0.01}
# {'loss': 0.7003, 'grad_norm': 96.6801986694336, 'learning_rate': 4.7e-05, 'rewards/chosen': -1.0838290452957153, 'rewards/rejected': -1.3502297401428223, 'rewards/accuracies': 0.5, 'rewards/margins': 0.2664005756378174, 'logps/chosen': -349.79827880859375, 'logps/rejected': -402.53155517578125, 'logits/chosen': 2.9885878562927246, 'logits/rejected': 2.5732085704803467, 'epoch': 0.01}
# {'loss': 0.5501, 'grad_norm': 87.38700866699219, 'learning_rate': 4.75e-05, 'rewards/chosen': -0.3448256552219391, 'rewards/rejected': -0.7879389524459839, 'rewards/accuracies': 0.875, 'rewards/margins': 0.4431133270263672, 'logps/chosen': -333.5886535644531, 'logps/rejected': -212.4319610595703, 'logits/chosen': 4.228625774383545, 'logits/rejected': 4.2163848876953125, 'epoch': 0.01}
# {'loss': 0.4879, 'grad_norm': 87.02632141113281, 'learning_rate': 4.8e-05, 'rewards/chosen': -0.3700374364852905, 'rewards/rejected': -0.9834628701210022, 'rewards/accuracies': 0.75, 'rewards/margins': 0.6134254932403564, 'logps/chosen': -408.155517578125, 'logps/rejected': -323.4049987792969, 'logits/chosen': 4.520632743835449, 'logits/rejected': 4.210874557495117, 'epoch': 0.01}
# {'loss': 0.5961, 'grad_norm': 93.96714782714844, 'learning_rate': 4.85e-05, 'rewards/chosen': -0.708962082862854, 'rewards/rejected': -1.272352933883667, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5633907914161682, 'logps/chosen': -470.462890625, 'logps/rejected': -378.7209777832031, 'logits/chosen': 3.128150463104248, 'logits/rejected': 3.2028613090515137, 'epoch': 0.01}
# {'loss': 0.4917, 'grad_norm': 90.66460418701172, 'learning_rate': 4.9e-05, 'rewards/chosen': -0.7055666446685791, 'rewards/rejected': -1.402878999710083, 'rewards/accuracies': 0.75, 'rewards/margins': 0.6973122954368591, 'logps/chosen': -673.6529541015625, 'logps/rejected': -623.6668090820312, 'logits/chosen': 3.273883581161499, 'logits/rejected': 4.256284236907959, 'epoch': 0.01}
# {'loss': 0.7151, 'grad_norm': 119.23014831542969, 'learning_rate': 4.9500000000000004e-05, 'rewards/chosen': -0.9161167144775391, 'rewards/rejected': -1.003420114517212, 'rewards/accuracies': 0.375, 'rewards/margins': 0.08730337023735046, 'logps/chosen': -485.1831970214844, 'logps/rejected': -455.94561767578125, 'logits/chosen': 3.7225942611694336, 'logits/rejected': 4.846094131469727, 'epoch': 0.01}
# {'loss': 0.5865, 'grad_norm': 102.03056335449219, 'learning_rate': 5e-05, 'rewards/chosen': -0.3673384487628937, 'rewards/rejected': -0.6689049005508423, 'rewards/accuracies': 0.75, 'rewards/margins': 0.30156639218330383, 'logps/chosen': -304.04046630859375, 'logps/rejected': -276.775634765625, 'logits/chosen': 3.6304585933685303, 'logits/rejected': 3.223991632461548, 'epoch': 0.01}
# {'loss': 0.6139, 'grad_norm': 118.06359100341797, 'learning_rate': 4.998766400914329e-05, 'rewards/chosen': -0.7171218991279602, 'rewards/rejected': -1.0237457752227783, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3066238760948181, 'logps/chosen': -407.2227783203125, 'logps/rejected': -347.21490478515625, 'logits/chosen': 2.434324026107788, 'logits/rejected': 1.803227424621582, 'epoch': 0.01}
# {'loss': 0.6805, 'grad_norm': 80.82518005371094, 'learning_rate': 4.995066821070679e-05, 'rewards/chosen': -0.657457172870636, 'rewards/rejected': -0.7766615748405457, 'rewards/accuracies': 0.625, 'rewards/margins': 0.11920440196990967, 'logps/chosen': -367.2481689453125, 'logps/rejected': -298.4210205078125, 'logits/chosen': 1.9362958669662476, 'logits/rejected': 2.4950029850006104, 'epoch': 0.01}
# {'loss': 0.6655, 'grad_norm': 105.3139877319336, 'learning_rate': 4.9889049115077005e-05, 'rewards/chosen': -0.599157989025116, 'rewards/rejected': -0.7078044414520264, 'rewards/accuracies': 0.5, 'rewards/margins': 0.10864643007516861, 'logps/chosen': -526.78369140625, 'logps/rejected': -345.4635314941406, 'logits/chosen': 3.3029589653015137, 'logits/rejected': 2.5446391105651855, 'epoch': 0.01}
# {'loss': 0.9853, 'grad_norm': 107.98795318603516, 'learning_rate': 4.980286753286195e-05, 'rewards/chosen': -0.6949745416641235, 'rewards/rejected': -0.4444725513458252, 'rewards/accuracies': 0.5, 'rewards/margins': -0.25050199031829834, 'logps/chosen': -317.02294921875, 'logps/rejected': -307.422119140625, 'logits/chosen': 2.9882209300994873, 'logits/rejected': 2.6494932174682617, 'epoch': 0.01}
# {'loss': 1.0359, 'grad_norm': 180.93820190429688, 'learning_rate': 4.9692208514878444e-05, 'rewards/chosen': -0.9524494409561157, 'rewards/rejected': -0.6565930843353271, 'rewards/accuracies': 0.5, 'rewards/margins': -0.29585638642311096, 'logps/chosen': -520.4097900390625, 'logps/rejected': -633.3062133789062, 'logits/chosen': 2.241950750350952, 'logits/rejected': 3.3597612380981445, 'epoch': 0.01}
# {'loss': 0.6779, 'grad_norm': 88.43885040283203, 'learning_rate': 4.9557181268217227e-05, 'rewards/chosen': -0.6478703618049622, 'rewards/rejected': -0.9803630113601685, 'rewards/accuracies': 0.5, 'rewards/margins': 0.3324925899505615, 'logps/chosen': -269.86590576171875, 'logps/rejected': -267.0324401855469, 'logits/chosen': 3.247030258178711, 'logits/rejected': 2.881121873855591, 'epoch': 0.01}
# {'loss': 0.5506, 'grad_norm': 92.48180389404297, 'learning_rate': 4.939791904846869e-05, 'rewards/chosen': -0.9705196022987366, 'rewards/rejected': -1.3412748575210571, 'rewards/accuracies': 0.75, 'rewards/margins': 0.37075531482696533, 'logps/chosen': -529.1944580078125, 'logps/rejected': -409.2028503417969, 'logits/chosen': 2.82523775100708, 'logits/rejected': 3.261061191558838, 'epoch': 0.01}
# {'loss': 0.8769, 'grad_norm': 129.75732421875, 'learning_rate': 4.9214579028215776e-05, 'rewards/chosen': -1.2731125354766846, 'rewards/rejected': -1.1621227264404297, 'rewards/accuracies': 0.625, 'rewards/margins': -0.11098971962928772, 'logps/chosen': -306.67694091796875, 'logps/rejected': -205.32484436035156, 'logits/chosen': 2.71417236328125, 'logits/rejected': 4.22592306137085, 'epoch': 0.01}
# {'loss': 0.8428, 'grad_norm': 123.2198257446289, 'learning_rate': 4.900734214192358e-05, 'rewards/chosen': -1.0953937768936157, 'rewards/rejected': -1.1562469005584717, 'rewards/accuracies': 0.75, 'rewards/margins': 0.06085314601659775, 'logps/chosen': -541.5863037109375, 'logps/rejected': -218.17059326171875, 'logits/chosen': 4.239048957824707, 'logits/rejected': 4.892877578735352, 'epoch': 0.01}
# {'loss': 1.1917, 'grad_norm': 253.7412872314453, 'learning_rate': 4.877641290737884e-05, 'rewards/chosen': -1.6210932731628418, 'rewards/rejected': -1.195941686630249, 'rewards/accuracies': 0.625, 'rewards/margins': -0.42515134811401367, 'logps/chosen': -522.2543334960938, 'logps/rejected': -764.0540771484375, 'logits/chosen': 3.7205817699432373, 'logits/rejected': 4.587287425994873, 'epoch': 0.01}
# {'loss': 0.8436, 'grad_norm': 134.46722412109375, 'learning_rate': 4.852201922385564e-05, 'rewards/chosen': -1.0617940425872803, 'rewards/rejected': -0.9183135032653809, 'rewards/accuracies': 0.375, 'rewards/margins': -0.14348047971725464, 'logps/chosen': -191.88150024414062, 'logps/rejected': -320.1101989746094, 'logits/chosen': 3.8959264755249023, 'logits/rejected': 5.194211959838867, 'epoch': 0.01}
# {'loss': 0.807, 'grad_norm': 94.75737762451172, 'learning_rate': 4.8244412147206284e-05, 'rewards/chosen': -0.48235830664634705, 'rewards/rejected': -0.6869641542434692, 'rewards/accuracies': 0.625, 'rewards/margins': 0.204605832695961, 'logps/chosen': -469.8884582519531, 'logps/rejected': -244.99441528320312, 'logits/chosen': 2.9723923206329346, 'logits/rejected': 2.2223520278930664, 'epoch': 0.01}
# {'loss': 0.5325, 'grad_norm': 102.41968536376953, 'learning_rate': 4.794386564209953e-05, 'rewards/chosen': -0.4996521472930908, 'rewards/rejected': -1.1966180801391602, 'rewards/accuracies': 0.75, 'rewards/margins': 0.6969658732414246, 'logps/chosen': -294.9522705078125, 'logps/rejected': -511.81732177734375, 'logits/chosen': 4.984417915344238, 'logits/rejected': 3.208594799041748, 'epoch': 0.01}
# {'loss': 0.5202, 'grad_norm': 79.2157974243164, 'learning_rate': 4.762067631165049e-05, 'rewards/chosen': -0.8271336555480957, 'rewards/rejected': -1.3435382843017578, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5164046883583069, 'logps/chosen': -280.488037109375, 'logps/rejected': -356.69317626953125, 'logits/chosen': 3.419116497039795, 'logits/rejected': 4.160113334655762, 'epoch': 0.01}
# {'loss': 0.5611, 'grad_norm': 121.67515563964844, 'learning_rate': 4.72751631047092e-05, 'rewards/chosen': -0.9465650320053101, 'rewards/rejected': -1.352910041809082, 'rewards/accuracies': 0.75, 'rewards/margins': 0.40634503960609436, 'logps/chosen': -588.9547119140625, 'logps/rejected': -389.25384521484375, 'logits/chosen': 2.063206911087036, 'logits/rejected': 3.238255262374878, 'epoch': 0.01}
# {'loss': 0.694, 'grad_norm': 87.53868103027344, 'learning_rate': 4.690766700109659e-05, 'rewards/chosen': -0.7427929639816284, 'rewards/rejected': -0.8346898555755615, 'rewards/accuracies': 0.5, 'rewards/margins': 0.09189688414335251, 'logps/chosen': -313.77813720703125, 'logps/rejected': -151.80532836914062, 'logits/chosen': 2.587242603302002, 'logits/rejected': 0.7556836605072021, 'epoch': 0.01}
# {'loss': 0.8852, 'grad_norm': 125.37458801269531, 'learning_rate': 4.65185506750986e-05, 'rewards/chosen': -1.0683046579360962, 'rewards/rejected': -0.8118026852607727, 'rewards/accuracies': 0.25, 'rewards/margins': -0.2565019726753235, 'logps/chosen': -416.2446594238281, 'logps/rejected': -433.50048828125, 'logits/chosen': 2.6670708656311035, 'logits/rejected': 3.5873775482177734, 'epoch': 0.02}
# {'loss': 0.7847, 'grad_norm': 106.2013931274414, 'learning_rate': 4.610819813755038e-05, 'rewards/chosen': -1.0678186416625977, 'rewards/rejected': -1.0631015300750732, 'rewards/accuracies': 0.5, 'rewards/margins': -0.004717126488685608, 'logps/chosen': -348.8907165527344, 'logps/rejected': -334.83587646484375, 'logits/chosen': 2.8966875076293945, 'logits/rejected': 1.991250991821289, 'epoch': 0.02}
# {'loss': 0.4469, 'grad_norm': 72.8378677368164, 'learning_rate': 4.567701435686404e-05, 'rewards/chosen': -0.9036428928375244, 'rewards/rejected': -1.766333818435669, 'rewards/accuracies': 0.75, 'rewards/margins': 0.8626910448074341, 'logps/chosen': -325.96343994140625, 'logps/rejected': -352.5670166015625, 'logits/chosen': 2.756641387939453, 'logits/rejected': 3.5332727432250977, 'epoch': 0.02}
# {'loss': 0.7909, 'grad_norm': 131.7562255859375, 'learning_rate': 4.522542485937369e-05, 'rewards/chosen': -1.5047963857650757, 'rewards/rejected': -1.3902071714401245, 'rewards/accuracies': 0.375, 'rewards/margins': -0.11458928883075714, 'logps/chosen': -438.38592529296875, 'logps/rejected': -281.2426452636719, 'logits/chosen': 3.405895948410034, 'logits/rejected': 2.781587600708008, 'epoch': 0.02}
# {'loss': 0.5976, 'grad_norm': 112.30899810791016, 'learning_rate': 4.4753875309392266e-05, 'rewards/chosen': -0.75469571352005, 'rewards/rejected': -1.2467225790023804, 'rewards/accuracies': 0.625, 'rewards/margins': 0.49202680587768555, 'logps/chosen': -478.186279296875, 'logps/rejected': -464.41680908203125, 'logits/chosen': 0.9402726888656616, 'logits/rejected': 0.6546493768692017, 'epoch': 0.02}
# ...
# {'loss': 0.6439, 'grad_norm': 111.85833740234375, 'learning_rate': 1.5071302734130489e-05, 'rewards/chosen': -1.0920400619506836, 'rewards/rejected': -1.3601107597351074, 'rewards/accuracies': 0.5, 'rewards/margins': 0.26807069778442383, 'logps/chosen': -280.98095703125, 'logps/rejected': -346.74859619140625, 'logits/chosen': 3.094135046005249, 'logits/rejected': 2.7590525150299072, 'epoch': 0.02}
# {'loss': 0.8888, 'grad_norm': 120.7435531616211, 'learning_rate': 1.4355517710873184e-05, 'rewards/chosen': -1.401808738708496, 'rewards/rejected': -1.4122589826583862, 'rewards/accuracies': 0.5, 'rewards/margins': 0.010450094938278198, 'logps/chosen': -289.1741943359375, 'logps/rejected': -302.64617919921875, 'logits/chosen': 3.7278800010681152, 'logits/rejected': 2.2444982528686523, 'epoch': 0.02}
# {'loss': 0.5953, 'grad_norm': 119.92130279541016, 'learning_rate': 1.3650237506511331e-05, 'rewards/chosen': -0.8579240441322327, 'rewards/rejected': -1.554457426071167, 'rewards/accuracies': 0.625, 'rewards/margins': 0.6965333223342896, 'logps/chosen': -324.44012451171875, 'logps/rejected': -286.5551452636719, 'logits/chosen': 3.1118416786193848, 'logits/rejected': 3.609508752822876, 'epoch': 0.02}
# {'loss': 1.1911, 'grad_norm': 186.9248504638672, 'learning_rate': 1.2956158147457115e-05, 'rewards/chosen': -1.864959716796875, 'rewards/rejected': -1.548555850982666, 'rewards/accuracies': 0.5, 'rewards/margins': -0.3164038062095642, 'logps/chosen': -623.97802734375, 'logps/rejected': -457.2720947265625, 'logits/chosen': 2.2784433364868164, 'logits/rejected': 1.5969786643981934, 'epoch': 0.02}
# {'loss': 0.9141, 'grad_norm': 182.48829650878906, 'learning_rate': 1.2273964606240718e-05, 'rewards/chosen': -1.7272720336914062, 'rewards/rejected': -1.8023006916046143, 'rewards/accuracies': 0.375, 'rewards/margins': 0.07502859830856323, 'logps/chosen': -588.97998046875, 'logps/rejected': -534.59423828125, 'logits/chosen': 2.1218578815460205, 'logits/rejected': 3.233734607696533, 'epoch': 0.02}
# {'loss': 0.7594, 'grad_norm': 119.89363098144531, 'learning_rate': 1.1604330125525079e-05, 'rewards/chosen': -0.8568271398544312, 'rewards/rejected': -0.8614262342453003, 'rewards/accuracies': 0.5, 'rewards/margins': 0.0045991092920303345, 'logps/chosen': -301.33001708984375, 'logps/rejected': -443.7326965332031, 'logits/chosen': 3.035484790802002, 'logits/rejected': 2.61773681640625, 'epoch': 0.02}
# {'loss': 0.6104, 'grad_norm': 101.55211639404297, 'learning_rate': 1.0947915553696742e-05, 'rewards/chosen': -0.9503446817398071, 'rewards/rejected': -1.3289803266525269, 'rewards/accuracies': 0.875, 'rewards/margins': 0.3786356449127197, 'logps/chosen': -366.31170654296875, 'logps/rejected': -302.4546203613281, 'logits/chosen': 3.1419548988342285, 'logits/rejected': 3.374208450317383, 'epoch': 0.02}
# {'loss': 0.7569, 'grad_norm': 119.30774688720703, 'learning_rate': 1.0305368692688174e-05, 'rewards/chosen': -1.1174737215042114, 'rewards/rejected': -1.1703287363052368, 'rewards/accuracies': 0.5, 'rewards/margins': 0.05285497009754181, 'logps/chosen': -604.9251098632812, 'logps/rejected': -405.919189453125, 'logits/chosen': 1.5465441942214966, 'logits/rejected': 3.423224449157715, 'epoch': 0.02}
# {'loss': 0.6772, 'grad_norm': 133.09963989257812, 'learning_rate': 9.677323658675594e-06, 'rewards/chosen': -0.8702978491783142, 'rewards/rejected': -1.3113303184509277, 'rewards/accuracies': 0.625, 'rewards/margins': 0.4410324692726135, 'logps/chosen': -426.9215087890625, 'logps/rejected': -359.955078125, 'logits/chosen': 2.365476369857788, 'logits/rejected': 2.8765616416931152, 'epoch': 0.02}
# {'loss': 0.7901, 'grad_norm': 122.05004119873047, 'learning_rate': 9.064400256282757e-06, 'rewards/chosen': -1.4412825107574463, 'rewards/rejected': -1.4604500532150269, 'rewards/accuracies': 0.625, 'rewards/margins': 0.01916757971048355, 'logps/chosen': -250.43272399902344, 'logps/rejected': -331.88934326171875, 'logits/chosen': 2.4670894145965576, 'logits/rejected': 3.383911609649658, 'epoch': 0.02}
# {'loss': 0.5203, 'grad_norm': 85.73685455322266, 'learning_rate': 8.467203366908707e-06, 'rewards/chosen': -1.3194681406021118, 'rewards/rejected': -2.112196683883667, 'rewards/accuracies': 0.75, 'rewards/margins': 0.7927285432815552, 'logps/chosen': -396.1532287597656, 'logps/rejected': -349.6972351074219, 'logits/chosen': 3.0752902030944824, 'logits/rejected': 2.70066237449646, 'epoch': 0.02}
# {'loss': 0.3832, 'grad_norm': 48.971614837646484, 'learning_rate': 7.886322351782783e-06, 'rewards/chosen': -0.8666207790374756, 'rewards/rejected': -2.1629397869110107, 'rewards/accuracies': 0.75, 'rewards/margins': 1.2963190078735352, 'logps/chosen': -164.1844482421875, 'logps/rejected': -414.043212890625, 'logits/chosen': 2.4681966304779053, 'logits/rejected': 2.3795676231384277, 'epoch': 0.02}
# {'loss': 0.8433, 'grad_norm': 144.3725128173828, 'learning_rate': 7.3223304703363135e-06, 'rewards/chosen': -0.9678747653961182, 'rewards/rejected': -0.7691667675971985, 'rewards/accuracies': 0.375, 'rewards/margins': -0.19870802760124207, 'logps/chosen': -488.51513671875, 'logps/rejected': -278.6812744140625, 'logits/chosen': 2.434950828552246, 'logits/rejected': 4.251025199890137, 'epoch': 0.02}
# {'loss': 0.8287, 'grad_norm': 123.37709045410156, 'learning_rate': 6.775784314464717e-06, 'rewards/chosen': -1.520881175994873, 'rewards/rejected': -1.3541152477264404, 'rewards/accuracies': 0.375, 'rewards/margins': -0.16676592826843262, 'logps/chosen': -406.567138671875, 'logps/rejected': -380.18505859375, 'logits/chosen': 2.9833827018737793, 'logits/rejected': 4.4904656410217285, 'epoch': 0.02}
# {'loss': 0.6954, 'grad_norm': 99.49977111816406, 'learning_rate': 6.247223259238513e-06, 'rewards/chosen': -1.0280566215515137, 'rewards/rejected': -1.7594386339187622, 'rewards/accuracies': 0.75, 'rewards/margins': 0.7313820123672485, 'logps/chosen': -574.2964477539062, 'logps/rejected': -336.379638671875, 'logits/chosen': 1.4949100017547607, 'logits/rejected': 2.243307113647461, 'epoch': 0.02}
# {'loss': 0.7773, 'grad_norm': 127.72078704833984, 'learning_rate': 5.737168930605272e-06, 'rewards/chosen': -1.477865219116211, 'rewards/rejected': -1.6160707473754883, 'rewards/accuracies': 0.5, 'rewards/margins': 0.1382056176662445, 'logps/chosen': -424.2021484375, 'logps/rejected': -475.63275146484375, 'logits/chosen': 2.9781830310821533, 'logits/rejected': 4.063063621520996, 'epoch': 0.02}
# {'loss': 0.7348, 'grad_norm': 118.69273376464844, 'learning_rate': 5.24612469060774e-06, 'rewards/chosen': -1.3699078559875488, 'rewards/rejected': -1.6455695629119873, 'rewards/accuracies': 0.5, 'rewards/margins': 0.27566173672676086, 'logps/chosen': -656.342529296875, 'logps/rejected': -429.74652099609375, 'logits/chosen': 2.597891092300415, 'logits/rejected': 2.2973151206970215, 'epoch': 0.02}
# {'loss': 0.6766, 'grad_norm': 97.154296875, 'learning_rate': 4.7745751406263165e-06, 'rewards/chosen': -1.3858437538146973, 'rewards/rejected': -1.5775139331817627, 'rewards/accuracies': 0.625, 'rewards/margins': 0.19167006015777588, 'logps/chosen': -384.8699951171875, 'logps/rejected': -275.7117614746094, 'logits/chosen': 1.559712529182434, 'logits/rejected': 1.196216106414795, 'epoch': 0.02}
# {'loss': 0.7342, 'grad_norm': 138.51953125, 'learning_rate': 4.322985643135952e-06, 'rewards/chosen': -1.2772959470748901, 'rewards/rejected': -1.3126682043075562, 'rewards/accuracies': 0.75, 'rewards/margins': 0.03537239134311676, 'logps/chosen': -434.62530517578125, 'logps/rejected': -406.0166320800781, 'logits/chosen': 3.877450466156006, 'logits/rejected': 2.6987576484680176, 'epoch': 0.02}
# {'loss': 0.3959, 'grad_norm': 78.6225357055664, 'learning_rate': 3.891801862449629e-06, 'rewards/chosen': -0.6312268972396851, 'rewards/rejected': -1.428896427154541, 'rewards/accuracies': 0.875, 'rewards/margins': 0.797669529914856, 'logps/chosen': -421.8724060058594, 'logps/rejected': -399.7384033203125, 'logits/chosen': 4.091832637786865, 'logits/rejected': 5.06743049621582, 'epoch': 0.02}
# {'loss': 0.5921, 'grad_norm': 125.18673706054688, 'learning_rate': 3.4814493249014116e-06, 'rewards/chosen': -1.1211607456207275, 'rewards/rejected': -1.4573099613189697, 'rewards/accuracies': 0.5, 'rewards/margins': 0.33614933490753174, 'logps/chosen': -630.197998046875, 'logps/rejected': -397.8676452636719, 'logits/chosen': 3.6289002895355225, 'logits/rejected': 1.8120354413986206, 'epoch': 0.02}
# {'loss': 0.9052, 'grad_norm': 126.51993560791016, 'learning_rate': 3.0923329989034132e-06, 'rewards/chosen': -1.5572210550308228, 'rewards/rejected': -1.5980501174926758, 'rewards/accuracies': 0.625, 'rewards/margins': 0.0408291220664978, 'logps/chosen': -626.19091796875, 'logps/rejected': -440.8482666015625, 'logits/chosen': 2.3021774291992188, 'logits/rejected': 2.6489524841308594, 'epoch': 0.02}
# {'loss': 0.8138, 'grad_norm': 121.19981384277344, 'learning_rate': 2.7248368952908053e-06, 'rewards/chosen': -1.091489553451538, 'rewards/rejected': -1.0159168243408203, 'rewards/accuracies': 0.625, 'rewards/margins': -0.07557263970375061, 'logps/chosen': -375.5810852050781, 'logps/rejected': -342.753662109375, 'logits/chosen': 3.5932369232177734, 'logits/rejected': 3.2021965980529785, 'epoch': 0.02}
# {'loss': 0.549, 'grad_norm': 84.54988861083984, 'learning_rate': 2.379323688349516e-06, 'rewards/chosen': -0.8822906017303467, 'rewards/rejected': -1.2731808423995972, 'rewards/accuracies': 0.875, 'rewards/margins': 0.39089030027389526, 'logps/chosen': -403.1266784667969, 'logps/rejected': -295.0398864746094, 'logits/chosen': 4.226016998291016, 'logits/rejected': 3.3553895950317383, 'epoch': 0.02}
# {'loss': 0.5764, 'grad_norm': 70.50849151611328, 'learning_rate': 2.0561343579004715e-06, 'rewards/chosen': -0.9450041055679321, 'rewards/rejected': -1.512723684310913, 'rewards/accuracies': 0.875, 'rewards/margins': 0.567719578742981, 'logps/chosen': -409.2095947265625, 'logps/rejected': -269.18499755859375, 'logits/chosen': 3.428356170654297, 'logits/rejected': 4.17410945892334, 'epoch': 0.02}
# {'loss': 1.0134, 'grad_norm': 146.43179321289062, 'learning_rate': 1.7555878527937164e-06, 'rewards/chosen': -1.6792285442352295, 'rewards/rejected': -1.3700472116470337, 'rewards/accuracies': 0.375, 'rewards/margins': -0.3091813921928406, 'logps/chosen': -446.75921630859375, 'logps/rejected': -490.1098327636719, 'logits/chosen': 1.3458729982376099, 'logits/rejected': 3.9250173568725586, 'epoch': 0.02}
# {'loss': 0.5524, 'grad_norm': 89.168212890625, 'learning_rate': 1.4779807761443636e-06, 'rewards/chosen': -1.1728541851043701, 'rewards/rejected': -1.7252311706542969, 'rewards/accuracies': 0.625, 'rewards/margins': 0.5523770451545715, 'logps/chosen': -506.2837219238281, 'logps/rejected': -406.5203857421875, 'logits/chosen': 3.0147743225097656, 'logits/rejected': 3.778873920440674, 'epoch': 0.02}
# {'loss': 0.4745, 'grad_norm': 108.82218170166016, 'learning_rate': 1.2235870926211619e-06, 'rewards/chosen': -0.9166386127471924, 'rewards/rejected': -1.4894219636917114, 'rewards/accuracies': 0.875, 'rewards/margins': 0.572783350944519, 'logps/chosen': -480.07330322265625, 'logps/rejected': -346.2142028808594, 'logits/chosen': 1.7689992189407349, 'logits/rejected': 1.5525132417678833, 'epoch': 0.02}
# {'loss': 0.6506, 'grad_norm': 134.2999725341797, 'learning_rate': 9.926578580764234e-07, 'rewards/chosen': -1.1017028093338013, 'rewards/rejected': -1.843932032585144, 'rewards/accuracies': 0.75, 'rewards/margins': 0.7422293424606323, 'logps/chosen': -400.30889892578125, 'logps/rejected': -475.7095947265625, 'logits/chosen': 2.904465675354004, 'logits/rejected': 2.8207836151123047, 'epoch': 0.02}
# {'loss': 0.5913, 'grad_norm': 117.70175170898438, 'learning_rate': 7.854209717842231e-07, 'rewards/chosen': -0.9718509912490845, 'rewards/rejected': -1.9526740312576294, 'rewards/accuracies': 0.75, 'rewards/margins': 0.9808230996131897, 'logps/chosen': -528.1027221679688, 'logps/rejected': -694.7403564453125, 'logits/chosen': 2.9220783710479736, 'logits/rejected': 4.052776336669922, 'epoch': 0.02}
# {'loss': 0.7442, 'grad_norm': 110.51603698730469, 'learning_rate': 6.020809515313142e-07, 'rewards/chosen': -1.0126793384552002, 'rewards/rejected': -1.0312213897705078, 'rewards/accuracies': 0.625, 'rewards/margins': 0.018542088568210602, 'logps/chosen': -378.44647216796875, 'logps/rejected': -321.74603271484375, 'logits/chosen': 3.3499035835266113, 'logits/rejected': 3.130509614944458, 'epoch': 0.02}
# {'loss': 0.5728, 'grad_norm': 69.14158630371094, 'learning_rate': 4.4281873178278475e-07, 'rewards/chosen': -0.8540490865707397, 'rewards/rejected': -1.3182775974273682, 'rewards/accuracies': 0.625, 'rewards/margins': 0.46422848105430603, 'logps/chosen': -388.9645690917969, 'logps/rejected': -194.06016540527344, 'logits/chosen': 2.2921648025512695, 'logits/rejected': 2.463684320449829, 'epoch': 0.02}
# {'loss': 0.5377, 'grad_norm': 83.12175750732422, 'learning_rate': 3.077914851215585e-07, 'rewards/chosen': -0.8329722881317139, 'rewards/rejected': -1.3381314277648926, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5051591396331787, 'logps/chosen': -399.14105224609375, 'logps/rejected': -201.65478515625, 'logits/chosen': 1.395249843597412, 'logits/rejected': 2.812324047088623, 'epoch': 0.03}
# {'loss': 0.417, 'grad_norm': 93.6998519897461, 'learning_rate': 1.9713246713805588e-07, 'rewards/chosen': -0.8160900473594666, 'rewards/rejected': -1.5323799848556519, 'rewards/accuracies': 1.0, 'rewards/margins': 0.7162899971008301, 'logps/chosen': -473.9012451171875, 'logps/rejected': -345.64898681640625, 'logits/chosen': 2.796767234802246, 'logits/rejected': 3.410303831100464, 'epoch': 0.03}
# {'loss': 0.802, 'grad_norm': 111.7511215209961, 'learning_rate': 1.109508849230001e-07, 'rewards/chosen': -1.3961877822875977, 'rewards/rejected': -1.5196853876113892, 'rewards/accuracies': 0.5, 'rewards/margins': 0.12349747121334076, 'logps/chosen': -608.812255859375, 'logps/rejected': -653.7562255859375, 'logits/chosen': 3.261579751968384, 'logits/rejected': 4.737407207489014, 'epoch': 0.03}
# {'loss': 0.553, 'grad_norm': 133.42564392089844, 'learning_rate': 4.9331789293211026e-08, 'rewards/chosen': -0.6274614334106445, 'rewards/rejected': -1.7009012699127197, 'rewards/accuracies': 0.625, 'rewards/margins': 1.0734400749206543, 'logps/chosen': -737.3207397460938, 'logps/rejected': -769.0472412109375, 'logits/chosen': 2.044546127319336, 'logits/rejected': 1.5804792642593384, 'epoch': 0.03}
# {'loss': 0.6306, 'grad_norm': 99.47086334228516, 'learning_rate': 1.233599085671e-08, 'rewards/chosen': -1.0470194816589355, 'rewards/rejected': -1.2346317768096924, 'rewards/accuracies': 0.75, 'rewards/margins': 0.18761217594146729, 'logps/chosen': -302.5430908203125, 'logps/rejected': -279.2402648925781, 'logits/chosen': 3.998553514480591, 'logits/rejected': 3.511314868927002, 'epoch': 0.03}
# {'loss': 0.4808, 'grad_norm': 68.19996643066406, 'learning_rate': 0.0, 'rewards/chosen': -0.7941294312477112, 'rewards/rejected': -1.584280252456665, 'rewards/accuracies': 0.625, 'rewards/margins': 0.7901507616043091, 'logps/chosen': -365.1143493652344, 'logps/rejected': -204.5275115966797, 'logits/chosen': 1.5615119934082031, 'logits/rejected': 0.6992111206054688, 'epoch': 0.03}
# {'train_runtime': 761.5575, 'train_samples_per_second': 2.101, 'train_steps_per_second': 0.263, 'train_loss': 0.6841798594594002, 'epoch': 0.03}
# TrainOutput(global_step=200, training_loss=0.6841798594594002, metrics={'train_runtime': 761.5575, 'train_samples_per_second': 2.101, 'train_steps_per_second': 0.263, 'total_flos': 0.0, 'train_loss': 0.6841798594594002, 'epoch': 0.025749967812540235})

# %% [markdown]
# ### Training seems to be more stable than DPO training of my model tuned on smoltalk :)

# %%
# Save the model
trainer.save_model(f"./{finetune_name}")

# Save to the huggingface hub if login (HF_TOKEN is set)
if os.getenv("HF_TOKEN"):
    trainer.push_to_hub(tags=finetune_tags)
# Out:
# model.safetensors:   0%|          | 0.00/538M [00:00<?, ?B/s]
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/6.07k [00:00<?, ?B/s]

# %% [markdown]
# ## 💐 You're done!
#
# This notebook provided a step-by-step guide to fine-tuning the `HuggingFaceTB/SmolLM2-135M` model using the `DPOTrainer`. By following these steps, you can adapt the model to perform specific tasks more effectively. If you want to carry on working on this course, here are steps you could try out:
#
# - Try this notebook on a harder difficulty
# - Review a colleagues PR
# - Improve the course material via an Issue or PR.
